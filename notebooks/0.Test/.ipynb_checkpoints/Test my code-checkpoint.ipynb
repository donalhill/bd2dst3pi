# %%
import numpy as np
import zfit
import matplotlib.pyplot as plt
import json
#Gives us nice LaTeX fonts in the plots
from matplotlib import rc
rc('font',**{'family':'serif','serif':['Roman']})
rc('text', usetex=True)


from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets


import sys
sys.path.append(loc.SCRIPTS)
import functions as f
from fit import launch_fit, plot_hist_fit, save_params, plot_hist_fit_particle
# Out:
# Welcome to JupyROOT 6.22/02

# %%
df_MC = f.load_data(years[:-1],magnets[:-1],type_data = 'MC',vars = ['B0_M','tau_M'],cut_DeltaM = True)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_up_Sim09e-ReDecay01.root
# cut on Delta_M

# %%
f.plot_hist({'MC':df_MC},'B0_M','B0\_M (MC)','MeV/$c^2$', n_bins = 100,name_folder = 'test',mode_hist=True,colors='black')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/test/B0_M_MC.pdf

# %%
f.plot_hist_particle({'MC data':df_MC}, 'B0_M', '0.2', n_bins = 100, name_data_title=True, 
                     name_folder = 'test', mode_hist=True, colors='black')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/test/B0_M_MC_data_BDT0.2.pdf

# %%
low_B0_M = 5050.
high_B0_M = 5550.
f.plot_hist2d(df_MC,['B0_M','tau_M'],['B0\_M','tau\_M'],['MeV/$c^2$','MeV/$c^2$'],low=[low_B0_M,None],high=[high_B0_M,None],
            name_folder = 'test', n_bins=100)

f.plot_hist2d_particle(df_MC,['B0_M','tau_M'],low=[low_B0_M,None],high=[high_B0_M,None],
                       name_data_title=True, 
                       name_folder = 'test', name_data='MC', n_bins=100)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/test/B0_M_vs_tau_M.pdf
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/test/B0_M_vs_tau_M_MC.pdf

# %%
low_B0_M = 5050.
high_B0_M = 5550.

f.plot_divide({'MC':df_MC,'data':df_MC},'B0_M','B0\_M','MeV/$c^2$',
              low=low_B0_M, high=high_B0_M,
            name_folder = 'test', n_bins=100)

f.plot_divide_particle({'MC':df_MC,'data':df_MC},'B0_M',
              low=low_B0_M, high=high_B0_M,
            name_folder = 'test', n_bins=100)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/functions.py:754: RuntimeWarning: invalid value encountered in true_divide
#   err = division*np.sqrt((err1/counts1)**2+(err2/counts2)**2)
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/test/B0_M_MC_d_data.pdf
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/functions.py:754: RuntimeWarning: invalid value encountered in true_divide
#   err = division*np.sqrt((err1/counts1)**2+(err2/counts2)**2)
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/test/B0_M_MC_d_data.pdf

# %%
low = 5050.
high = 5550.
obs = zfit.Space("x", limits=(low, high))
mu_MC = zfit.Parameter("mu_MC", 5280., 5250., 5300.)
sigma_MC = zfit.Parameter("sigma_MC", 20., 10., 60.)
alphaL_MC = zfit.Parameter("alphaL_MC", 2., 0.1, 5.)
alphaR_MC = zfit.Parameter("alphaR_MC", 2., 0.1, 5.)
nL_MC = zfit.Parameter("nL_MC", 2., 0.01, 10.)
nR_MC = zfit.Parameter("nR_MC", 2., 0.01, 10.)
name_params = {
    'mu_MC':'$\mu$',
    'sigma_MC':'$\sigma$',
    'alphaL_MC':'$\\alpha_L$',
    'alphaR_MC':'$\\alpha_R$',
    'nL_MC':'$n_L$',
    'nR_MC':'$n_R$',
}
n = zfit.Parameter("n", df_MC['B0_M']/2, 0, len(df_MC['B0_M']))
doubleCB_MC = zfit.pdf.DoubleCB(mu_MC, sigma_MC, alphaL_MC, alphaR_MC, nL_MC, nR_MC, obs=obs)
doubleCB_MC_ext = doubleCB_MC.create_extended(n)
data_MC = zfit.Data.from_pandas(df_MC['B0_M'],obs=obs)

# %%
result, params = launch_fit(doubleCB_MC, data_MC)
# Out:
# ------------------------------------------------------------------
# | FCN = 8414                    |     Ncalls=376 (376 total)     |
# | EDM = 0.000473 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name         value    minuit_hesse         minuit_minos    at limit
# ---------  -------  --------------  -------------------  ----------
# alphaL_MC    1.273     +/-    0.13  -   0.13   +   0.13       False
# nL_MC        1.698     +/-    0.35  -   0.25   +   0.39       False
# mu_MC         5281     +/-    0.47  -   0.47   +   0.47       False
# alphaR_MC    4.006     +/-    0.91  -   0.77   +   0.99       False
# nR_MC        7.171     +/-     5.1  -    3.6   +    2.8       False
# sigma_MC     14.06     +/-    0.75  -   0.74   +   0.67       False
# Info: VariableMetricBuilder: Tolerance is not sufficient, continue the minimization
# Info in Current  Edm is : edm = 0.00234352
# Info in Required Edm is : edmval = 0.001

# %%
plot_hist_fit(df_MC,'B0_M',None,'$MeV/c^2$',models = doubleCB_MC, obs=obs, n_bins = 100,mode_hist = False,
              name_folder = 'test',name_data = 'MC',params=params,name_params=name_params)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/fit.py:391: UserWarning: The function <function Space.limits at 0x7f5522f3d4d0> may does not return the actual area/limits but rather the rectangular limits. <zfit Space obs=('x',), axes=None, limits=(array([[5050.]]), array([[5550.]]))> can also have functional limits that are arbitrarily defined and lay inside the rect_limits. To test if a value is inside, use `inside` or `filter`.
#   low = float(obs.limits[0])
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/fit.py:35: UserWarning: The function <function Space.area at 0x7f5522f428c0> may does not return the actual area/limits but rather the rectangular limits. <zfit Space obs=('x',), axes=None, limits=(array([[5050.]]), array([[5550.]]))> can also have functional limits that are arbitrarily defined and lay inside the rect_limits. To test if a value is inside, use `inside` or `filter`.
#   return counts.sum() * obs.area() / n_bins
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/test/B0_M_MC_fit.pdf

# %%
plot_hist_fit_particle(df_MC,'B0_M', models = doubleCB_MC, obs=obs, n_bins = 100,mode_hist = False,
              name_folder = 'test',name_data = 'MC',params=params,name_params=name_params)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/test/B0_M_MC_fit.pdf

# %%
plot_hist_fit_particle(df_MC,'B0_M', models = [doubleCB_MC_ext,doubleCB_MC_ext],
                       name_models = ['$B^0\\to D^*D_s$','$B^0\\to D^*3\pi h$'],
                       obs=obs, n_bins = 100,mode_hist = False,
              name_folder = 'test',name_data = 'MC',cut_BDT = 0.2, params=params,name_params=name_params)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/fit.py:391: UserWarning: The function <function Space.limits at 0x7fa3585353b0> may does not return the actual area/limits but rather the rectangular limits. <zfit Space obs=('x',), axes=None, limits=(array([[5050.]]), array([[5550.]]))> can also have functional limits that are arbitrarily defined and lay inside the rect_limits. To test if a value is inside, use `inside` or `filter`.
#   low = float(obs.limits[0])
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/fit.py:35: UserWarning: The function <function Space.area at 0x7fa35853a7a0> may does not return the actual area/limits but rather the rectangular limits. <zfit Space obs=('x',), axes=None, limits=(array([[5050.]]), array([[5550.]]))> can also have functional limits that are arbitrarily defined and lay inside the rect_limits. To test if a value is inside, use `inside` or `filter`.
#   return counts.sum() * obs.area() / n_bins
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-7-1119d520ee68> in <module>
#       2                        name_models = ['$B^0\\to D^*D_s$','$B^0\\to D^*3\pi h$'],
#       3                        obs=obs, n_bins = 100,mode_hist = False,
# ----> 4               name_folder = 'test',name_data = 'MC',cut_BDT = 0.2, params=params,name_params=name_params)
#
# ~/bd2dst3pi/scripts/fit.py in plot_hist_fit_particle(df, variable, models, obs, n_bins, color, name_models, mode_hist, linewidth, colors, name_data_title, title, name_file, name_folder, name_data, cut_BDT, params, name_params, colWidths)
#     528                   name_data_title=name_data_title, title=title,
#     529                   name_file=name_file,name_folder=name_folder,name_data=name_data,
# --> 530                   params=params,name_params=name_params, colWidths=colWidths)
#
# ~/bd2dst3pi/scripts/fit.py in plot_hist_fit(df, variable, name_var, unit_var, models, obs, n_bins, color, name_models, mode_hist, linewidth, colors, name_data_title, title, name_file, name_folder, name_data, params, name_params, colWidths)
#     424     #plot_fitted_curve(ax[0], model, plot_scaling, low, high)
#     425     plot_fitted_curves(ax[0], models, plot_scaling, low, high, name_models=name_models,
# --> 426                        line_width=2.5, colors=colors, fontsize_legend=20)
#     427
#     428     ## Plot pull histogram
#
# ~/bd2dst3pi/scripts/fit.py in plot_fitted_curves(ax, models, plot_scaling, low, high, name_models, line_width, colors, fontsize_legend)
#     205         label_model = fct.add_text(label_model, name_models[k])
#     206         plot_fitted_curve(ax, model, plot_scaling, frac=frac, line_width=2.5, color=colors[k],
# --> 207                           linestyle = ls, label=label_model, x=x)
#     208
#     209     if show_legend:
#
# ~/bd2dst3pi/scripts/fit.py in plot_fitted_curve(ax, model, plot_scaling, frac, line_width, color, linestyle, low, high, label, x)
#     141     if x is None:
#     142         x = np.linspace(low, high, 1000)
# --> 143     y = frac_model(x, model, frac=frac)* plot_scaling
#     144     ax.plot(x, y, linewidth=line_width, color=color, ls=linestyle, label=label)
#     145
#
# ~/bd2dst3pi/scripts/fit.py in frac_model(x, model, frac)
#      61         return model.pdf(x).numpy()
#      62     else:
# ---> 63         return (model.pdf(x)*frac).numpy()
#      64
#      65 def el_or_list_to_group(l, type_el=np.ndarray):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in binary_op_wrapper(x, y)
#    1122     with ops.name_scope(None, op_name, [x, y]) as name:
#    1123       try:
# -> 1124         return func(x, y, name=name)
#    1125       except (TypeError, ValueError) as e:
#    1126         # Even if dispatching the op failed, the RHS may be a tensor aware
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in _mul_dispatch(x, y, name)
#    1454     return sparse_tensor.SparseTensor(y.indices, new_vals, y.dense_shape)
#    1455   else:
# -> 1456     return multiply(x, y, name=name)
#    1457
#    1458
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/tensorflow/python/util/dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py in multiply(x, y, name)
#     506   """
#     507
# --> 508   return gen_math_ops.mul(x, y, name)
#     509
#     510
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/tensorflow/python/ops/gen_math_ops.py in mul(x, y, name)
#    6164       return _result
#    6165     except _core._NotOkStatusException as e:
# -> 6166       _ops.raise_from_not_ok_status(e, name)
#    6167     except _core._FallbackException:
#    6168       pass
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Incompatible shapes: [1000] vs. [1922] [Op:Mul]

# %%
doubleCB_MC.name

# %%
lambd = zfit.Parameter("lambda", -0.0008, -0.01, -0.0001)

# %%
exponential_B0Ds = zfit.pdf.Exponential(lambd, obs=obs)

# %%
frac = zfit.Parameter("frac", 0.5, 1, 1)

# %%
model_B0Ds = zfit.pdf.SumPDF([doubleCB_MC, exponential_B0Ds],fracs = frac)

# %%
model_B0Ds.name

# %%
exponential_B0Ds.name
# Out:
# 'Exponential'
