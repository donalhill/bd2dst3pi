# %%
import zfit
import numpy as np

from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets

import sys
sys.path.append(loc.SCRIPTS)
import functions as fct

# %% [markdown]
# ## Load data

# %%
variables = ['B0_M','tau_M']
df_data_strip = fct.load_data(years[:-1], magnets[:-1], type_data='data_strip', vars=variables,
                            cut_DeltaM=True)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2015_up.root

# %%
df_MC = fct.load_data(years, magnets, type_data='MC', vars=variables, cut_DeltaM=True)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_up_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_down_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2016_up_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2016_down_Sim09e-ReDecay01.root
# cut on PIDs have removed 245 over 23724 events

# %% [markdown]
# ## Test of my code

# %%
fct.plot_hist_particle({'data_strip_cutDeltaM':df_data_strip},'tau_pion0_ID',
              n_bins = 100, mode_hist = False)
fct.plot_hist_particle({'data_strip_cutDeltaM':df_data_strip},'tau_pion1_ID',
              n_bins = 100, mode_hist = False)
fct.plot_hist_particle({'data_strip_cutDeltaM':df_data_strip},'tau_pion2_ID',
              n_bins = 100, mode_hist = False)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM/tau_pion0_ID_data_strip_cutDeltaM.pdf
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM/tau_pion1_ID_data_strip_cutDeltaM.pdf
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM/tau_pion2_ID_data_strip_cutDeltaM.pdf

# %%
fct.plot_hist_particle({'data_strip_cutDeltaM':df_data_strip},'Dst_ID',
              n_bins = 100, mode_hist = False)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM/Dst_ID_data_strip_cutDeltaM.pdf

# %%
fct.plot_hist_particle({'data strip':df_data_strip, 'MC': df_MC}, 'tau_pion0_PIDK',
                       name_folder='data_strip_cutDeltaM_PID', low=-0, high=10.,
                       n_bins=100, mode_hist=False)
fct.plot_hist_particle({'data strip':df_data_strip, 'MC': df_MC}, 'tau_pion1_PIDK',
                       name_folder='data_strip_cutDeltaM_PID', low=-0., high=10.,
                       n_bins=100, mode_hist=False)
fct.plot_hist_particle({'data strip':df_data_strip, 'MC': df_MC}, 'tau_pion2_PIDK',
                       name_folder='data_strip_cutDeltaM_PID', low=-0., high=10.,
                       n_bins=100, mode_hist=False)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM_PID/tau_pion0_PIDK_data_strip_MC.pdf
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM_PID/tau_pion1_PIDK_data_strip_MC.pdf
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM_PID/tau_pion2_PIDK_data_strip_MC.pdf

# %% [markdown]
# ## Save the data
# I save the data in order not to have to cut every time!!

# %%
variables = ['B0_M','tau_M', 'BDT']

df_data_strip = fct.load_data(years, magnets, type_data='data_strip', vars=variables,
                            cut_DeltaM=True, cut_PID=True)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2015_up.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2015_down.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2016_up.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2016_down.root
# cut on PIDs have removed 296374 over 2955949 events

# %%
fct.save_dataframe(df_data_strip, 'data_strip', 'data_strip_cutDeltaM_cutPID')

# %% [markdown]
# I can remember that: **cut on PIDs have removed 296374 over 2955949 events: there are 2659575 events**

# %% [markdown]
# ## Test the saved data

# %%
variables = ['tau_pion0_PIDK']
df_data_strip = fct.load_data(years, magnets, type_data='data_strip', vars=variables,
                            cut_DeltaM=True, cut_PID=True)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/data_strip.root

# %%
fct.plot_hist_particle({'data strip':df_data_strip}, 'tau_pion0_PIDK',
                       name_folder='data_strip_cutDeltaM_PID', low=-0, high=10.,
                       n_bins=100, mode_hist=False)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM_PID/tau_pion0_PIDK_data_strip.pdf

# %%
print(df_data_strip.columns)
# Out:
# Index(['tau_pion0_PIDK'], dtype='object')
