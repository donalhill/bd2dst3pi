# %% [markdown]
# Once the BDT is applied, it must be tested.
# In this file, we load `B0_M` and `BDT` variables and plot:
# - `BDT`
# - `B0_M` for different cuts on the `BDT` variable

# %%
import matplotlib.pyplot as plt
from bd2dst3pi.locations import loc


from bd2dst3pi.definitions import years, magnets

import sys
sys.path.append(loc.SCRIPTS)
from load_save_data import load_data 
import plot.histogram as h
# Out:
# Welcome to JupyROOT 6.22/02

# %% [markdown]
# # Test `adaboost_without_P_with_cut_deltaM` for 80% of ws data

# %% [markdown]
# ## Load data

# %%
name_BDT = 'adaboost_0.8_without_P_cutDeltaM'

# %%
variables = ['B0_M','BDT']

# %%
df = load_data(years,magnets,type_data = 'common',vars = variables)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/all_common.root

# %%
print(df)
# Out:
#                B0_M       BDT
# 4       4760.873029 -0.047250
# 6       4998.158261  0.423655
# 9       3984.862607 -0.427085
# 10      5037.392182  0.300843
# 12      4900.875432  0.343151
# ...             ...       ...
# 419972  3349.663864 -0.169197
# 419976  3247.692412 -0.394461
# 419977  3171.289485 -0.225968
# 419978  3372.445255  0.193689
# 419979  4148.482373  0.403345
#
# [510173 rows x 2 columns]

# %% [markdown]
# ### BDT plot

# %%
h.plot_hist({'$BDT':df},'BDT', 'BDT', '', n_bins = 50,mode_hist=False, colors='orangered', 
            name_file = 'BDT',name_folder = name_BDT)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/adaboost_0.8_without_P_cutDeltaM/BDT.pdf
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='BDT', ylabel='Candidates / (0.03)'>)

# %% [markdown]
# ### `BO_M`

# %%
low = 5150.
high = 5550.

h.plot_hist_particle({'no cut':df, '$BDT>0$':df.query('BDT>0'), 
            '$BDT<0$':df.query('BDT<0')},
          'B0_M', n_bins = 100,low = low,high=high,mode_hist=True, 
                       colors=['b', 'g', 'r'],
            name_file = 'BDT_cut_on_B0_M',name_folder = name_BDT, density=False)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/adaboost_0.8_without_P_cutDeltaM/BDT_cut_on_B0_M.pdf
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='$m$($D^{*}3\\pi$) [MeV/$c^2$]', ylabel='Candidates / (4 MeV/$c^2$)'>)

# %%
low = 5150.
high = 5550.

h.plot_hist_particle({'no cut':df, '$BDT>0$':df.query('BDT>0')},
          'B0_M', n_bins = 100,low = low,high=high,mode_hist=True, 
                       colors=['b', 'g', 'r'],
            name_file = 'BDT_cut_on_B0_M',name_folder = name_BDT, density=False)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/adaboost_0.8_without_P_cutDeltaM/BDT_cut_on_B0_M.pdf
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='$m$($D^{*}3\\pi$) [MeV/$c^2$]', ylabel='Candidates / (4 MeV/$c^2$)'>)

# %%
low = 5050.
high = 5550.

h.plot_hist_particle({'$BDT>0.1$':df.query('BDT>0.1'),
             '$BDT>0$':df.query('BDT>0'),
             '$BDT>-0.1$':df.query('BDT>-0.1')},
          'B0_M', low = low, high=high, mode_hist=True,
            name_file = 'BDT_different_cut_on_B0_M',name_folder=name_BDT)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/adaboost_0.8_without_P_cutDeltaM/BDT_different_cut_on_B0_M.pdf
