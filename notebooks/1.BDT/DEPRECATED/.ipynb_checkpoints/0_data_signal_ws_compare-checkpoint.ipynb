# %%
import zfit
import json

from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets

import sys
sys.path.append(loc.SCRIPTS)
import functions as fct
from fit import launch_fit, save_params, plot_hist_fit, plot_hist_fit_particle
# Out:
# Welcome to JupyROOT 6.22/02

# %%
df = {}
variables = ['B0_M','tau_M', 'BDT', 'Dst_M', 'D0_M']

# %%
df['data_strip'] = fct.load_data(years, magnets, type_data='data_strip', vars=variables,
                            cut_DeltaM=False)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2015_up.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2015_down.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2016_up.root

# %%
df['MC'] = fct.load_data(years, magnets, type_data='data_strip', vars=variables,
                            cut_DeltaM=False)

# %% [markdown]
# ## Distributions

# %%
fct.plot_hist_particle({'data_strip_cutDeltaM':df_data_strip},'B0_M',
              n_bins = 100, mode_hist = False,colors='black')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM/B0_M_data_strip_cutDeltaM.pdf

# %%
fct.plot_hist_particle({'data_strip_cutDeltaM':df_data_strip},'tau_M',
              n_bins = 100, mode_hist = False,colors='black')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_cutDeltaM/tau_M_data_strip_cutDeltaM.pdf

# %% [markdown]
# ## $\Delta M = m(D^*) - m(D^0)$

# %%
for k in 'data_strip', 'MC':
    df[k]["Delta_M"] = df["Dst_M"] - df["D0_M"]

# %%
fct.plot_hist({'data_strip_cutDeltaM':df_data_strip},'tau_M',
              n_bins = 100, mode_hist = False,colors='black')
