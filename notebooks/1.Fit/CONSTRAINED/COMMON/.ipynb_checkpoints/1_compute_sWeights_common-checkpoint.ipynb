# %% [markdown]
# # Name data: `common_Dstto3piHEP`
#
# # Compute the sWeights
# 1. Fit on $m(3\pi)$ for $|m(3\pi) - 1968|<50$
#     - Signal shape: Gaussian
#     - Background shape: Exponential
# 2. Compute the associated probability and sWeights
# 3. Plot the sWeight (as a check)
# 4. Save the sWeight in a root file
#
# The sWeights are computed with `hepstats` (and not `hep_ml`). This is why I added `HEP` to the name of the data.
#
# The root files is saved in `output/root/common/`

# %%
data_name = 'common_DstTO3pi'

# %%
import zfit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from hepstats.splot import compute_sweights

from bd2dst3pi.locations import loc
from bd2dst3pi.definition import years, magnets, latex_params_tau
from bd2dst3pi.pandas_root import load_data, add_constr_Dst

import sys
sys.path.append(loc.ROOT + 'library/')

from HEA.plot import plot_hist_auto, plot_hist, plot_hist2d_auto
from HEA.plot.fit import plot_hist_fit_auto
from HEA.fit import json_to_latex_table, retrieve_params, show_latex_table
from HEA.fit.fit import launch_fit, save_params, define_zparams
from HEA.tools import show_dictionnary
from HEA.plot.tools import save_fig, show_grid
from HEA.tools.serial import dump_pickle
from HEA.pandas_root import save_root
# Out:
# Welcome to JupyROOT 6.22/02

# %% [markdown]
# ## Retrieve data

# %%
df = load_data(years, magnets, type_data='common', vars=['B0_M','tau_M', 'Dst_M'],
                            cut_DeltaM=True)
df = add_constr_Dst(df)
# Out:
# Loading /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//common/data/data_90000000_2015_up.root
# Loading /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//common/data/data_90000000_2015_down.root
# Loading /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//common/data/data_90000000_2016_up.root
# Loading /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//common/data/data_90000000_2016_down.root
# Delta_M > 143. and Delta_M < 148. cut has removed 425088 over 935261 events

# %%
size_tau_M = 50.
mean_tau_M = 1969.
low_tau_M = mean_tau_M - size_tau_M
high_tau_M = mean_tau_M + size_tau_M
df_Ds = df.query(f"abs(tau_M-{mean_tau_M})<={size_tau_M}")

# %% [markdown]
# ## Histogram

# %%
plot_hist_auto({data_name:df_Ds},'tau_M',
              n_bins = 100, bar_mode = False, colors='black', pos_text_LHC='right')
# Out:
# Figure saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots//common_DstTO3pi/tau_M_common_DstTO3pi
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='$m$($3\\pi$) [MeV/$c^2$]', ylabel='Candidates / (1 MeV/$c^2$)'>)

# %% [markdown]
# ## Fit to $m(3\pi)$ = gaussian (signal) + exponential (background)

# %% [markdown]
# ### Initial conditions

# %%
n_events_tau_M = len(df_Ds)
initial_values_tau = {
    'mu_tau': {
        'value' : 1969.,
        'low': 1965.,
        'high': 1975.,     
    },
    'sigma_tau': {
        'value' : 9.4,
        'low': 5.,
        'high': 15.,
    },
    'n_bkg_tau': {
        'value' : n_events_tau_M*2/3,
        'low': 0,
        'high': n_events_tau_M,  
    },
    'n_sig_tau': {
        'value' : n_events_tau_M/3,
        'low': 0,
        'high': n_events_tau_M,  
    },
    'lambda_tau': {
        'value' : -0.003,
        'low': -0.01,
        'high': -0.0001  
    }
}

# %% [markdown]
# ### Parameters and pdf

# %%
obs_tau = zfit.Space("x", limits=(low_tau_M, high_tau_M))

zparams_tau = define_zparams(initial_values_tau)

# %%
gaussian_tau = zfit.pdf.Gauss(zparams_tau["mu_tau"],zparams_tau["sigma_tau"],obs=obs_tau)
exponential_tau = zfit.pdf.Exponential(zparams_tau["lambda_tau"], obs=obs_tau)

gaussian_ext_tau = gaussian_tau.create_extended(zparams_tau["n_sig_tau"])
exp_ext_tau = exponential_tau.create_extended(zparams_tau["n_bkg_tau"])
model_tau = zfit.pdf.SumPDF([gaussian_ext_tau, exp_ext_tau]) # gauss is folded by frac

data_tau = zfit.Data.from_pandas(df_Ds['tau_M'],obs=obs_tau)

# %% [markdown]
# ### Launch fit

# %%
import timeit
start = timeit.default_timer()
result_tau, params_tau = launch_fit(model_tau, data_tau, extended=True)
stop = timeit.default_timer()
print('Time to do the fit: ', stop - start)
# Out:
# ------------------------------------------------------------------
# | FCN = -7.151e+04              |     Ncalls=126 (126 total)     |
# | EDM = 4.61e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name            value    minuit_hesse    at limit
# ----------  ---------  --------------  ----------
# n_sig_tau        6816     +/- 1.3e+02       False
# n_bkg_tau        9932     +/- 1.4e+02       False
# mu_tau           1969     +/-    0.17       False
# sigma_tau       9.267     +/-    0.18       False
# lambda_tau  -0.003488     +/- 0.00037       False
# Time to do the fit:  1.2728708810172975

# %% [markdown]
# Result of the fit:
#
#     ------------------------------------------------------------------
#     | FCN = -7.151e+04              |     Ncalls=126 (126 total)     |
#     | EDM = 4.61e-05 (Goal: 0.001)  |            up = 0.5            |
#     ------------------------------------------------------------------
#     |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
#     ------------------------------------------------------------------
#     |     True      |     True      |   False   |       False        |
#     ------------------------------------------------------------------
#     | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
#     ------------------------------------------------------------------
#     |     False     |     True      |   True    |   True    | False  |
#     ------------------------------------------------------------------
#     name            value    minuit_hesse         minuit_minos    at limit
#     ----------  ---------  --------------  -------------------  ----------
#     n_sig_tau        6816     +/- 1.3e+02  -1.3e+02   +1.3e+02       False
#     n_bkg_tau        9932     +/- 1.4e+02  -1.4e+02   +1.4e+02       False
#     mu_tau           1969     +/-    0.17  -   0.17   +   0.18       False
#     sigma_tau       9.267     +/-    0.18  -   0.17   +   0.18       False
#     lambda_tau  -0.003488     +/- 0.00037  -0.00037   +0.00037       False
#     Time to do the fit:  2.776348260231316

# %%
plot_hist_fit_auto(df,'tau_M',models = [model_tau,gaussian_ext_tau,exp_ext_tau], 
                       models_names = ["", '\n $D_S^+ \\to 3\pi$',''], colors = ['b','r','y'],
                       obs=obs_tau, n_bins = 100,bar_mode = False, data_name=data_name+'_detail', 
                      params=params_tau,latex_params=latex_params_tau, fontsize_leg=15.)
plot_hist_fit_auto(df,'tau_M',models = [model_tau,gaussian_ext_tau,exp_ext_tau], 
                       models_names = ["", '\n $D_S^+ \\to 3\pi$',''], colors = ['b','r','y'],
                       obs=obs_tau, n_bins = 100,bar_mode = False, data_name=data_name, 
                       fontsize_leg=16., pos_text_LHC='right')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/library/HEA/plot/fit.py:761: UserWarning: The function <function Space.limits at 0x7fb482600cb0> may does not return the actual area/limits but rather the rectangular limits. <zfit Space obs=('x',), axes=None, limits=(array([[1919.]]), array([[2019.]]))> can also have functional limits that are arbitrarily defined and lay inside the rect_limits. To test if a value is inside, use `inside` or `filter`.
#   low = float(obs.limits[0])
# Number of bins: 100
# Width of the bins: 1.0
#
# Number of d.o.f. in the model:  5
# Reduced chi2:  1.1189082909460164
#
# Mean of the normalised residuals: -0.0465782822512479
# Std of the normalised residuals: 1.0299482220098441
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# Figure saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots//common_DstTO3pi_detail/tau_M_common_DstTO3pi_detail_fit
# Number of bins: 100
# Width of the bins: 1.0
#
# Number of d.o.f. in the model:  5
# Reduced chi2:  1.1189082909460164
#
# Mean of the normalised residuals: -0.0465782822512479
# Std of the normalised residuals: 1.0299482220098441
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# Figure saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots//common_DstTO3pi/tau_M_common_DstTO3pi_fit
# (<Figure size 864x720 with 2 Axes>,
#  <AxesSubplot:xlabel='$m$($3\\pi$) [MeV/$c^2$]', ylabel='Candidates / (1 MeV/$c^2$)'>,
#  <AxesSubplot:ylabel='residuals / $\\sigma$'>)

# %%
save_params(params_tau, data_name, True, folder_name=data_name)
# Out:
# Json file saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/test/common_DstTO3pi_params.json

# %%
json_to_latex_table(data_name, data_name, latex_params_tau)
# Out:
# Latex table in /afs/cern.ch/user/c/correian/bd2dst3pi/output/tables/common_DstTO3pi/common_DstTO3pi_params.tex
# \begin{tabular}[t]{lc}
# \hline
# Variable &Fitted Value\\
# \hline\hline
# $\lambda_{bkg,c}$&$-0.00349\pm0.00037$\\
# \hline
# $\mu_{S}$&$1968.59\pm0.17$\\
# \hline
# $n_{bkg,c}$&$(9.93\pm0.14)\times 10^3$\\
# \hline
# $n_{S}$&$(6.82\pm0.13)\times 10^3$\\
# \hline
# $\sigma_{S}$&$9.27\pm0.18$\\
# \hline
# \end{tabular}

# %% [markdown]
# ### Correlation between `B0_M`and `tau_M`.
# Theoretically speaking, in order to apply the sWeights to 'B0_M', those two variables must not be correlated.

# %%
from scipy.stats import pearsonr

# %%
low_B0Ds = 5150.
high_B0Ds = 5360.

# %%
branch = 'Dst_constr_B0_M'
df_Ds = add_constr_Dst(df_Ds)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/bd2dst3pi/pandas_root.py:193: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f"Dst_constr_{col}"] = df[col].values - df['Dst_M'].values + Dst_M_PDG

# %%
print(np.corrcoef(df_Ds['tau_M'], df_Ds[branch]) [0, 1])
print(pearsonr(df_Ds['tau_M'], df_Ds[branch])[0])
# Out:
# 0.047662460225687375
# 0.04766246022568738

# %%
np.corrcoef(df_Ds['tau_M'], df_Ds['B0_M']) [0, 1]
# Out:
# 0.04762547106585079

# %%
pearsonr(df_Ds['tau_M'], df_Ds['B0_M'])[0]
# Out:
# 0.04762547106585078

# %%
plot_hist2d_auto(df_Ds, ['tau_M','B0_M'],
            low=[low_tau_M, low_B0Ds], high=[high_tau_M, high_B0Ds], log_scale=True,
            folder_name=data_name)
# Out:
# Figure saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots//common_DstTO3pi/tau_M_vs_B0_M
# (<Figure size 576x432 with 2 Axes>,
#  <AxesSubplot:xlabel='$m$($3\\pi$) [MeV/$c^2$]', ylabel='$m$($D^{*}3\\pi$) [MeV/$c^2$]'>)

# %% [markdown]
# ## Compute sWeights via hepstats

# %% [markdown]
# ### Computation

# %%
weights_hep = compute_sweights(model_tau, df_Ds['tau_M'])

# %%
weights_sig = weights_hep[zparams_tau['n_sig_tau']]
weights_bkg = weights_hep[zparams_tau['n_bkg_tau']]

mass = df_Ds['tau_M']

# %% [markdown]
# ### Plotting

# %%
fig, ax = plt.subplots(figsize=(8,6))

ax.axhline(0, c='black', ls='-', alpha=0.1)
ax.axvline(float(zparams_tau['mu_tau']), c='red', ls='--')
ax.plot(mass, weights_sig,'.', label='$D_s^+ \\to 3\pi$ decays', markersize=1., color='r')
ax.plot(mass, weights_bkg,'.', label='Background', markersize=1., color='y')
ax.set_xlim(low_tau_M, high_tau_M)



plt.xlabel('$m(3\pi)$ [MeV/$c^2$]',fontsize=25)
plt.ylabel('sWeights',fontsize=25)

ymin, ymax = ax.get_ylim()
#ax.set_ylim(ymin, ymax*1.1)
pt.fix_plot(ax, factor_ymax=1.4, pos_text_LHC=[0.05, 0.95, 'left'], ymin_to_0=False)
ax.legend(markerscale=12, fontsize=20)
show_grid(ax)
plt.show()
plt.close()

save_fig(fig, 'sWeights', folder_name=data_name)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# Figure saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots//common_DstTO3pi/sWeights

# %% [markdown]
# ### Save the dataframe

# %%
sWeights_df = pd.DataFrame()
sWeights_df['sWeight'] = weights_sig

# %%
save_root(sWeights_df, data_name+'_sWeights', 'sWeights', folder_name='common')
# Out:
# Root file saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/test/common_DstTO3pi_sWeights.root

# %%
df_Ds['sWeight'] = weights_sig
# Out:
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
save_root(df_Ds, data_name, 'DecayTree', folder_name='common')
# Out:
# Root file saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/test/common_DstTO3pi.root
