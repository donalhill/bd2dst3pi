# %% [markdown]
# # MC vs background variables
#
# Goal:
# - Compare the training variables for the MC (signal) and for the background samples (for the BDT training)
# - Plot the correlation of the training variables (for the training of the BDTs)

# %%
name_BDT = 'gradient'
low_bkg = 5400
high_bkg = 5570

var = 'Dst_constr_B0_M'

# %%
from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets

import matplotlib.pyplot as plt
import numpy as np
import matplotlib

import sys
sys.path.append(loc.SCRIPTS)
from load_save_data import load_data, load_saved_root, save_dataframe, save_json, get_real_vars, get_needed_vars, get_df_variables, add_constr_Dst
import plot.histogram as h
from plot.tool import save_file
import BDT.BDT as bt
# Out:
# Welcome to JupyROOT 6.22/02

# %% [markdown]
# ## Load data

# %% [markdown]
# ### Training variables

# %%
variables_functions = [
    ('B0_DIRA_OWNPV', 'ln(1-x)'),
    (('B0_ENDVERTEX_CHI2', 'B0_ENDVERTEX_NDOF'), 'x/y'),
    'B0_PT',
    ('B0_FDCHI2_OWNPV', 'ln(x)'),
    'B0_IP_OWNPV', # much better with it
#     'B0_FD_OWNPV',

    ('Dst_DIRA_OWNPV', 'ln(1-x)'), # better with it
    'Dst_PT',
#     'Dst_FDCHI2_OWNPV', # worse with it
    'Dst_IPCHI2_OWNPV',
    'Dst_IP_OWNPV',
#     'Dst_FD_OWNPV', # different for sWeighted and MC

#     ('D0_DIRA_OWNPV', 'ln(1-x)'), # worst with it # different for sWeighted and MC
#     (('D0_ENDVERTEX_CHI2', 'D0_ENDVERTEX_NDOF'), 'x/y'),
    'D0_PT',
    ('D0_FDCHI2_OWNPV', 'ln(x)'),
    ('D0_IPCHI2_OWNPV', 'ln(x)'),
    'D0_IP_OWNPV',
#     'D0_FD_OWNPV', # different for sWeighted and MC

#     ('tau_DIRA_OWNPV', 'ln(1-x)'), # different for sWeighted and MC
    (('tau_ENDVERTEX_CHI2', 'tau_ENDVERTEX_NDOF'), 'x/y'), # a bit worse without it 
    'tau_PT',
    ('tau_FDCHI2_OWNPV', 'ln(x)'),
    ('tau_IPCHI2_OWNPV', 'ln(x)'),
    'tau_IP_OWNPV',
#     'tau_FD_OWNPV', # better without it # different for sWeighted and MC

    'Dst_pion_PT',
    ('Dst_pion_IPCHI2_OWNPV', 'ln(x)'),

    'D0_kaon_PT',
    ('D0_kaon_IPCHI2_OWNPV', 'ln(x)'),

    'D0_pion_PT', # better with it
    ('D0_pion_IPCHI2_OWNPV', 'ln(x)'),
       
#     'B0_ETA', # different for sWeighted and MC
#     'Dst_ETA', # different for sWeighted and MC
#     'D0_ETA', # different for sWeighted and MC
#     'tau_ETA', # different for sWeighted and MC
#     'Dst_pion_ETA', # different for sWeighted and MC
#     'D0_kaon_ETA', # different for sWeighted and MC
#     'D0_pion_ETA', # different for sWeighted and MC
]

needed_variables = get_needed_vars(variables_functions)
variables = get_real_vars(variables_functions)

    
add_variables = ['B0_M', 'tau_M', 'Dst_M', 'D0_M']

# %% [markdown]
# ### Load dataframes

# %%
df = {}
df['MC']     = load_data(years,magnets,type_data = 'MC'      ,vars = needed_variables+add_variables, cut_DeltaM=True, cut_PIDK=None)
df['training_MC'] = get_df_variables(df['MC'], variables_functions)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_up_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_down_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2016_up_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2016_down_Sim09e-ReDecay01.root
# cut on DeltaM has removed 0 over 23724 events

# %%
df['common'] = load_data(years,magnets,type_data = 'common'  ,vars = needed_variables+add_variables, cut_DeltaM=True, cut_PIDK=None)
df['common'] = add_constr_Dst(df['common'])
add_variables += [var]

# %% [markdown]
# ### Dataframes with the training variables

# %%
df['training_common'] = get_df_variables(df['common'], variables_functions + add_variables)

# %%
df['bkg'] = df['training_common'].query(f'{var} > {low_bkg} and {var} <{high_bkg}')

# %%
print(variables)
# Out:
# ['B0_DIRA_OWNPV:ln(1-x)', 'B0_ENDVERTEX_CHI2,B0_ENDVERTEX_NDOF:x/y', 'B0_PT', 'B0_FDCHI2_OWNPV:ln(x)', 'B0_IP_OWNPV', 'Dst_DIRA_OWNPV:ln(1-x)', 'Dst_PT', 'Dst_IPCHI2_OWNPV', 'Dst_IP_OWNPV', 'D0_PT', 'D0_FDCHI2_OWNPV:ln(x)', 'D0_IPCHI2_OWNPV:ln(x)', 'D0_IP_OWNPV', 'tau_ENDVERTEX_CHI2,tau_ENDVERTEX_NDOF:x/y', 'tau_PT', 'tau_FDCHI2_OWNPV:ln(x)', 'tau_IPCHI2_OWNPV:ln(x)', 'tau_IP_OWNPV', 'Dst_pion_PT', 'Dst_pion_IPCHI2_OWNPV:ln(x)', 'D0_kaon_PT', 'D0_kaon_IPCHI2_OWNPV:ln(x)', 'D0_pion_PT', 'D0_pion_IPCHI2_OWNPV:ln(x)']

# %%
for var in add_variables:
    for data in 'training_MC', 'bkg':
        try:
            df['bkg'] = df['bkg'].drop(var, 1)
        except KeyError:
            pass

# %% [markdown]
# ## Compare MC and background data

# %% [markdown]
# ### Range of the variables

# %%
range_dic = {
    'B0_PT': [0,35000],
    'Dst_PT':[0,30000],
    'tau_PT':[0,18000],
    'Dst_pion_PT':[0,2300],
    'Dst_kaon_PT':[0,2300],
    'D0_pion_PT':[0,20000],
    'D0_kaon_PT':[0,20000],
    'D0_PT':[0,3000],
    'B0_ENDVERTEX_CHI2':[0,60],
    'tau_ENDVERTEX_CHI2':[None,None],
    'B0_OWNPV_CHI2':[None,None],    
    'B0_FDCHI2_OWNPV':[0, 13000], 
    'B0_DIRA_OWNPV':[0.99996, 1], 
    'Dst_IPCHI2_OWNPV':[0, 2000], 
    'D0_kaon_IPCHI2_OWNPV':[0, 20000], 
    'D0_kaon_IPCHI2_OWNPV':[0, 20000], 
    'D0_pion_IPCHI2_OWNPV':[0, 20000], 
    'pion_IPCHI2_OWNPV':[0, 2000], 
    'tau_FDCHI2_OWNPV':[0, 200000], 
    'tau_FD_OWNPV':[0, 500], 
    'tau_pion0_TRACK_CHI2NDOF':[None,None], 
    'tau_pion1_TRACK_CHI2NDOF':[None,None], 
    'tau_pion2_TRACK_CHI2NDOF':[None,None],
    'D0_ENDVERTEX_CHI2,D0_ENDVERTEX_NDOF:x/y':[0, 10],
    'B0_ENDVERTEX_CHI2,B0_ENDVERTEX_NDOF:x/y':[0, 10],
    'B0_IP_OWNPV':[0, 0.1], 
    'D0_IP_OWNPV':[0, 2], 
    'Dst_IP_OWNPV':[0, 2], 
    'tau_IP_OWNPV':[0, 4], 
    'B0_FD_OWNPV':[0, 100], 
    'Dst_FD_OWNPV':[0, 200], 
    'tau_FD_OWNPV':[0, 150], 
    'D0_FD_OWNPV':[0, 200],
    "Dst_FDCHI2_OWNPV":[-1000, 20000],
}

# %% [markdown]
# ### Plots

# %%
for variable in variables:
    print(f"=====================  {variable} =====================")
    
    if variable in range_dic:
        low = range_dic[variable][0]
        high = range_dic[variable][1]
    else:
        low = None
        high = None
    
    fig, ax = h.plot_hist_particle({'MC': df['training_MC'], 'Background': df['bkg']}, variable, alpha=0.5, 
                                   n_bins=40, mode_hist = True, colors=['g', 'y'], low=low, high=high, 
                                   pos_text_LHC=[0.95, 0.95, 'right'], loc_leg = 'upper left',
                                   name_folder=f'BDT/{name_BDT}/variables',
                                   label_ncounts=False, save_fig=True)
# Out:
# =====================  B0_DIRA_OWNPV:ln(1-x) =====================
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/BDT/gradient/variables/B0_DIRA_OWNPV:ln(1-x)_MC_Background
# =====================  B0_ENDVERTEX_CHI2,B0_ENDVERTEX_NDOF:x/y =====================

# %% [markdown]
# ## Correlation matrix of the training variables for the signal and background samples

# %%
bt.correlations(df['training_MC'], title = 'MC', name_file=name_BDT+'_MC', name_folder=name_BDT)
bt.correlations(df['bkg'], title = 'Background', name_file=name_BDT+'_bkg', name_folder=name_BDT)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/BDT/gradient/corr_matrix_gradient_MC
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/BDT/gradient/corr_matrix_gradient_bkg
# (<Figure size 864x720 with 2 Axes>,
#  <AxesSubplot:title={'center':'Correlations - Background'}>)

# %% [markdown]
# ## EXAMPLE - 2D scatter plots
# (Illustration of MVA)

# %% [markdown]
# ### Variables

# %%
var1 = 'B0_FDCHI2_OWNPV:ln(x)'
var2 = 'D0_IPCHI2_OWNPV:ln(x)'

variables = [var1, var2, 'BDT', 'Dst_constr_B0_M']

# %% [markdown]
# ### `common` dataset
# I need to replace `__` by `:` because:
# - `root_pandas` cannot save columns with `:`
# - Thus, I saved them with `__` instead but I need to replace that by `:` so that my scripts recognise the variable

# %%
df['common'] = load_saved_root(f'common_{name_BDT}_full', name_folder='common')

columns = list(df['common'].columns)
for column in columns:
    if '__' in column:
        df['common'][column.replace('__', ':')] = df['common'][column].values
        df['common'] = df['common'].drop(column, 1)
        
df['bkg'] = df['common'].query(f'{var} > {low_bkg} and {var} <{high_bkg}')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output//root/common/common_gradient_full.root

# %%
df['common']
# Out:
#              BDT         B0_M  Dst_constr_B0_M  B0_FDCHI2_OWNPV:ln(x)  \
# 214044  1.777667  5269.832445      5277.770543               6.431495
# 377961 -1.816064  4424.983842      4417.761810               4.973866
# 205559 -3.390062  3621.585702      3634.870615               5.280597
# 118334 -0.185971  3780.021032      3799.289947               7.104354
# 106596 -6.441119  3112.789746      3119.626675               6.249278
# ...          ...          ...              ...                    ...
# 263109 -1.391342  4075.403048      4069.788423               7.323863
# 98121  -2.543706  5031.903417      5000.635068               5.309564
# 318088 -6.369187  3568.804001      3556.772727               4.625626
# 447071 -3.484617  5318.014103      5322.334298               7.129194
# 125363 -7.602335  3510.376760      3512.751990               6.032399
#
#         D0_IPCHI2_OWNPV:ln(x)
# 214044               5.360957
# 377961               3.605982
# 205559               3.703557
# 118334               5.239349
# 106596               6.022569
# ...                       ...
# 263109               6.242381
# 98121                3.951986
# 318088               4.612972
# 447071               5.847600
# 125363               6.509219
#
# [510173 rows x 5 columns]

# %% [markdown]
# ### Plotted dataframes and colors

# %%
dfs = {'Background':df['bkg'], 'Signal (MC)':df['training_MC'].sample(11016, random_state=50)}
colors = ['r', 'g']

# %%
dfs_LHCb = {'LHCb data':df['common'].sample(len(df['MC']), random_state=50), 'Signal (MC)':df['training_MC']}
colors_LHCb = ['b', 'g']

# %% [markdown]
# ### 2D scatter plots of the two variables  in the training signal and background sample

# %%
fig, ax = h.plot_scatter2d_particle(dfs, [var1, var2], name_folder='signal_vs_background', marker='.', s=1,
                        low=[2, None], high=[12.5, None], fontsize=17,
                       colors = colors)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/signal_vs_background/B0_FDCHI2_OWNPV:ln(x)_vs_D0_IPCHI2_OWNPV:ln(x)_Signal

# %%
# Fixing random state for reproducibility
np.random.seed(19680801)

# the random data
x = np.random.randn(1000)
y = np.random.randn(1000)

# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a rectangular Figure
fig = plt.figure(figsize=(8, 8))

ax_scatter = plt.axes(rect_scatter)
ax_scatter.tick_params(direction='in', top=True, right=True)
ax_histx = plt.axes(rect_histx)
ax_histx.tick_params(direction='in', labelbottom=False)
ax_histy = plt.axes(rect_histy)
ax_histy.tick_params(direction='in', labelleft=False)


scs = h.plot_scatter2d_particle(dfs, [var1, var2], name_folder='signal_vs_background', marker='.', s=1,
                        low=[2, None], high=[12.5, None], ax=ax_scatter, fontsize=14,
                       colors = colors, get_sc=True)

h.plot_hist_particle(dfs, var1, name_folder='signal_vs_background',
                        low=2, high=12.5,  ax=ax_histx, show_leg=False, fontsize=10, mode_hist=True,
                       colors = colors)
ax_histx.set_xlabel(None)
h.plot_hist_particle(dfs, var2, name_folder='signal_vs_background',
                        low=None, high=None,  ax=ax_histy, show_leg=False, orientation='horizontal',
                     mode_hist=True,
                     fontsize=10,
                       colors = colors)
ax_histy.set_ylabel(None)

ax_scatter.set_xlim(ax_histx.get_xlim())
ax_scatter.set_ylim(ax_histy.get_ylim())

xticks = ax_scatter.xaxis.get_major_ticks()
xticks[-2].label1.set_visible(False)

yticks = ax_scatter.yaxis.get_major_ticks()
yticks[-2].label1.set_visible(False)
yticks[-1].label1.set_visible(False)

ax_scatter.xaxis.labelpad = 10
ax_scatter.legend(fontsize=20, markerscale=10)

xmin, xmax = ax_histx.get_xlim()
ymin, ymax = ax_histy.get_ylim()
x = [3.5, 9.5]
y = [ymin, ymax]

ax_scatter.plot(x, y, color='k', linewidth=1., linestyle='--') 
ax_scatter.fill(x + [xmin, xmin], y + [ymax, ymin], 'r', alpha=0.1)


for sc in scs:
    sc.set_rasterized(True)
    sc.set_zorder(-20)

    
    
save_file(fig, 'scatter_plot_signal_bkg', name_folder='training_BDT')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/plot/histogram.py:324: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/plot/histogram.py:324: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/training_BDT/scatter_plot_signal_bkg

# %% [markdown]
# ### 2D scatter plots of the two variables in the MC and LHCb datasets

# %%
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a rectangular Figure
fig = plt.figure(figsize=(8, 8))

ax_scatter = plt.axes(rect_scatter)
ax_scatter.tick_params(direction='in', top=True, right=True)
ax_histx = plt.axes(rect_histx)
ax_histx.tick_params(direction='in', labelbottom=False)
ax_histy = plt.axes(rect_histy)
ax_histy.tick_params(direction='in', labelleft=False)



scs = h.plot_scatter2d_particle(dfs_LHCb, [var1, var2], name_folder='signal_vs_background', marker='.', s=1,
                        low=[2, None], high=[12.5, None], ax=ax_scatter, fontsize=14,
                       colors=colors_LHCb, get_sc=True)

h.plot_hist_particle(dfs_LHCb, var1, name_folder='signal_vs_background',
                        low=2, high=12.5,  ax=ax_histx, show_leg=False, fontsize=10, mode_hist=True,
                       colors=colors_LHCb)
ax_histx.set_xlabel(None)
h.plot_hist_particle(dfs_LHCb, var2, name_folder='signal_vs_background',
                        low=None, high=None,  ax=ax_histy, show_leg=False, orientation='horizontal',
                     mode_hist=True,
                     fontsize=10,
                       colors=colors_LHCb)
ax_histy.set_ylabel(None)

ax_scatter.set_xlim(ax_histx.get_xlim())
ax_scatter.set_ylim(ax_histy.get_ylim())

xticks = ax_scatter.xaxis.get_major_ticks()
xticks[-2].label1.set_visible(False)

yticks = ax_scatter.yaxis.get_major_ticks()
yticks[-2].label1.set_visible(False)
yticks[-1].label1.set_visible(False)

ax_scatter.xaxis.labelpad = 10
ax_scatter.legend(fontsize=20, markerscale=10)

for sc in scs:
    sc.set_rasterized(True)
    sc.set_zorder(-20)

ax_scatter.axvspan(2, 3.5, alpha=0.1, color='r')
ax_scatter.axvline(x=3.5, color='k', linewidth=1., linestyle='--') 
ax_histx.axvspan(2, 3.5, alpha=0.1, color='r')
ax_histx.axvline(x=3.5, color='k', linewidth=1., linestyle='--')     
    
save_file(fig, 'scatter_plot_signal_LHCb_1Dcut', name_folder='training_BDT')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/plot/histogram.py:324: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/plot/histogram.py:324: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/training_BDT/scatter_plot_signal_LHCb_1Dcut

# %%
# definitions for the axes
left, width = 0.1, 0.65
bottom, height = 0.1, 0.65
spacing = 0.005


rect_scatter = [left, bottom, width, height]
rect_histx = [left, bottom + height + spacing, width, 0.2]
rect_histy = [left + width + spacing, bottom, 0.2, height]

# start with a rectangular Figure
fig = plt.figure(figsize=(8, 8))

ax_scatter = plt.axes(rect_scatter)
ax_scatter.tick_params(direction='in', top=True, right=True)
ax_histx = plt.axes(rect_histx)
ax_histx.tick_params(direction='in', labelbottom=False)
ax_histy = plt.axes(rect_histy)
ax_histy.tick_params(direction='in', labelleft=False)



scs = h.plot_scatter2d_particle(dfs_LHCb, [var1, var2], name_folder='signal_vs_background', marker='.', s=1,
                        low=[2, None], high=[12.5, None], ax=ax_scatter, fontsize=14,
                       colors=colors_LHCb, get_sc=True)

h.plot_hist_particle(dfs_LHCb, var1, name_folder='signal_vs_background',
                        low=2, high=12.5,  ax=ax_histx, show_leg=False, fontsize=10, mode_hist=True,
                       colors=colors_LHCb)
ax_histx.set_xlabel(None)
h.plot_hist_particle(dfs_LHCb, var2, name_folder='signal_vs_background',
                        low=None, high=None,  ax=ax_histy, show_leg=False, orientation='horizontal',
                     mode_hist=True,
                     fontsize=10,
                       colors=colors_LHCb)
ax_histy.set_ylabel(None)

ax_scatter.set_xlim(ax_histx.get_xlim())
ax_scatter.set_ylim(ax_histy.get_ylim())

xticks = ax_scatter.xaxis.get_major_ticks()
xticks[-2].label1.set_visible(False)

yticks = ax_scatter.yaxis.get_major_ticks()
yticks[-2].label1.set_visible(False)
yticks[-1].label1.set_visible(False)

ax_scatter.xaxis.labelpad = 10
ax_scatter.legend(fontsize=20, markerscale=10)

for sc in scs:
    sc.set_rasterized(True)
    sc.set_zorder(-20)

    
ax_scatter.plot(x, y, color='black', linewidth=1., linestyle='--') 
ax_scatter.fill(x + [xmin, xmin], y + [ymax, ymin], 'r', alpha=0.1)


save_file(fig, 'scatter_plot_signal_LHCb_2Dcut', name_folder='training_BDT')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/plot/histogram.py:324: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/plot/histogram.py:324: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/training_BDT/scatter_plot_signal_LHCb_2Dcut

# %%
cm = matplotlib.colors.LinearSegmentedColormap.from_list("", ["red","green"])

# %%
# df_samp = df['common'].sample(200000, random_state=50)

# fig, ax = plt.subplots(figsize=(8,6))

# ax.plot(x, y, color='black', linewidth=1., linestyle='--') 
# ax.fill(x + [xmin, xmin], y + [ymax, ymin], 'r', alpha=0.1)

# sc = h.plot_scatter2d_particle({'LHCb data': df_samp}, 
#                                     [var1, var2], name_folder='signal_vs_background', 
#                                     marker='o', s=1,
#                                     low=[2, None], high=[12.5, None], fontsize=17, 
#                                     cmap=cm, get_sc=True, ax=ax,
#                                     colors=[df_samp['BDT']], save_fig=False)

# sc.set_rasterized(True)
# sc.set_zorder(-20)

# colorbar = plt.colorbar(sc)
# colorbar.ax.tick_params(labelsize=20)
# colorbar.set_label('BDT', fontsize=25)



# ax.set_ylim(ax_histy.get_ylim())
# ax.set_xlim(ax_histx.get_xlim())

# save_file(fig, 'scatter_plot_data', name_folder='training_BDT')

# %%
df_samp = df['common'].sample(200000, random_state=50)

fig, ax = plt.subplots(figsize=(8,6))

ax.fill(x + [xmin, xmin], y + [ymax, ymin], 'r', alpha=0.1)


cmap_cat = matplotlib.colors.ListedColormap(['r', 'g'])
norm = matplotlib.colors.BoundaryNorm([np.ceil(df_samp['BDT'].min()), -1.25, np.round(df_samp['BDT'].max())], cmap_cat.N) 

sc = h.plot_scatter2d_particle({'LHCb data': df_samp}, 
                                    [var1, var2], name_folder='signal_vs_background', 
                                    marker='o', s=1,
                                    low=[2, None], high=[12.5, None], fontsize=17, 
                                    get_sc=True, ax=ax, cmap=cmap_cat, norm=norm,
                                    colors=[df_samp['BDT']], 
                               save_fig=False)



colorbar = fig.colorbar(sc)
colorbar.ax.tick_params(labelsize=20)
colorbar.set_label('BDT', fontsize=25)

sc.set_rasterized(True)
sc.set_zorder(-20)

ax.set_ylim(ax_histy.get_ylim())
ax.set_xlim(ax_histx.get_xlim())


ax.plot(x, y, color='black', linewidth=1., linestyle='--') 

save_file(fig, 'scatter_plot_data', name_folder='training_BDT')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/training_BDT/scatter_plot_data
