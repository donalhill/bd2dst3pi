# %%
import matplotlib.pyplot as plt
from bd2dst3pi.locations import loc

#import numpy as np
#import pandas as pd

from bd2dst3pi.definitions import years, magnets

import sys
sys.path.append(loc.SCRIPTS)
import functions as fct

# %% [markdown]
# # Test `adaboost_without_P_with_cut_deltaM` for 80% of ws data

# %%
name_BDT = 'adaboost_0.8_without_P_cutDeltaM'

# %%
variables = ['B0_M','BDT']

# %%
df = {}
df = fct.load_data(years,magnets,type_data = 'data_strip',vars = variables)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//common/data/data_90000000_2015_up.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//common/data/data_90000000_2015_down.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//common/data/data_90000000_2016_up.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//common/data/data_90000000_2016_down.root
# cut on Delta_M
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-e3cb7c19a473> in <module>
#       1 df = {}
# ----> 2 df = fct.load_data(years,magnets,type_data = 'data_strip',vars = variables)
#
# ~/bd2dst3pi/scripts/functions.py in load_data(years, magnets, type_data, vars, method, name_BDT, cut_DeltaM, cut_PIDK)
#     286             dfr_tot = apply_cut_DeltaM(dfr_tot)
#     287         if mode_BDT:
# --> 288             dfr_tot['BDT'] = read_root(loc.OUT+f'tmp/{data}/BDT_{name_BDT}.root', 'BDT', columns=['BDT'])
#     289         if cut_PIDK == 'PID': # NB: cut the PID after adding the BDT branch :)
#     290             print('cut on PIDK')
#
# NameError: name 'data' is not defined

# %%
# df_tot['data_strip']['BDT'] = read_root(loc.OUT+f'tmp/BDT_{name_BDT}.root', 'BDT', columns=['BDT'])

# %%
fct.plot_hist({'$BDT':df_tot['data_strip']},'BDT', 'BDT', '', n_bins = 50,mode_hist=True, 
            name_file = 'BDT',name_folder = name_BDT)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/adaboost_0.8_without_P_cutDeltaM/BDT.pdf

# %%
low = 5050.
high = 5550.

fct.plot_hist({'$BDT<0$':df_tot['data_strip'].query('BDT<0'),
             '$BDT>0$':df_tot['data_strip'].query('BDT>0'),
              'no cut':df_tot['data_strip']},
          'B0_M', 'B0\_M', 'MeV/$c^2$', n_bins = 50,low = low,high=high,mode_hist=True, 
            name_file = 'BDT_cut_on_B0_M',name_folder = name_BDT)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/adaboost_0.8_without_P_cutDeltaM/BDT_cut_on_B0_M.pdf

# %%
low = 5050.
high = 5550.

fct.plot_hist({'$BDT>0.1$':df_tot['data_strip'].query('BDT>0.1'),
             '$BDT>0$':df_tot['data_strip'].query('BDT>0'),
             '$BDT>-0.1$':df_tot['data_strip'].query('BDT>-0.1')},
          'B0_M', 'B0\_M', 'MeV/$c^2$', n_bins = 50,low = low,high=high,mode_hist=True, 
            name_file = 'BDT_different_cut_on_B0_M',name_folder = name_BDT)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/adaboost_0.8_without_P_cutDeltaM/BDT_different_cut_on_B0_M.pdf
