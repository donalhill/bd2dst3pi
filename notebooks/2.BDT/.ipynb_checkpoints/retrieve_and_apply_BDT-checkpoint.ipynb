# %%
import zfit
import json

from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets

import sys
sys.path.append(loc.SCRIPTS)
import functions as fct
from fit import launch_fit, save_params, plot_hist_fit, plot_hist_fit_particle
# Out:
# Welcome to JupyROOT 6.22/02

# %%
df = {}
variables = ['B0_M','tau_M', 'Dst_M', 'D0_M']

# %%
df['data_strip'] = fct.load_data(years, magnets, type_data='data_strip', vars=variables,
                            cut_DeltaM=False)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2015_up.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2015_down.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2016_up.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//stripped/data/data_90000000_2016_down.root

# %%
df['MC'] = fct.load_data(years, magnets, type_data='MC', vars=variables,
                            cut_DeltaM=False)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_up_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_down_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2016_up_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2016_down_Sim09e-ReDecay01.root

# %% [markdown]
# ## Distributions

# %%
fct.plot_hist_particle({'data':df['data_strip'], 'MC':df['MC']},'B0_M',
              n_bins = 100, mode_hist = False)
# Out:
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_MC/B0_M_data_MC.pdf

# %%
fct.plot_hist_particle({'data_strip':df['data_strip']},'tau_M',
              n_bins = 100, mode_hist = False,colors='black')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip/tau_M_data_strip.pdf

# %% [markdown]
# ## $\Delta M = m(D^*) - m(D^0)$

# %%
for k in 'data_strip', 'MC':
    df[k]["Delta_M"] = df[k]["Dst_M"] - df[k]["D0_M"]

# %%
fct.plot_hist({'data':df['data_strip'], 'MC':df['MC']},'Delta_M','$\\Delta M$','MeV/$c^2$',
              n_bins = 100, mode_hist = True, name_folder='data_strip_MC')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip_MC/Delta_M_data_MC.pdf

# %%
fct.plot_hist({'data_strip':df['data_strip']},'Delta_M','$\\Delta M$','MeV/$c^2$',
              n_bins = 100, mode_hist = False, name_folder='data_strip', colors='black')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_strip/Delta_M_data_strip.pdf
