# %% [markdown]
# # Fit of `B0_M` of the recontructed $B^0 \to D^*K \pi^+\pi^-$ decay
# - **Model**: sum of
#     - A crystal ball with left powertail
#     - A crystal ball with right powertail
# - **Data** : `RapidSim` simulated of $B^0 \to D^*K \pi^+\pi^-$ with $K$ misidentified as a $\pi$ of same charge, **with constrained $m(D^*)$**

# %% [markdown]
# ## Libraries

# %%
import zfit
import pandas as pd
from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets


import sys
sys.path.append(loc.SCRIPTS)
from load_save_data import load_data, add_constr_Dst
import plot.histogram as h
from plot.fit import plot_hist_fit_particle
from fit import launch_fit, save_params
import plot.tool as pt
# Out:
# Welcome to JupyROOT 6.22/02

# %% [markdown]
# ## Retrieve data

# %%
variables = ['B0_M_Tau_Pi12pip', 'Dst_M', 'D0_M']
df = load_data(years, magnets, type_data='data_KPiPi', vars=variables)
for var in variables: # GeV --> MeV
    df[var] = 1000*df[var]
# Out:
# /afs/cern.ch/user/d/dhill/public/forAnthony/Bd2DstKPiPi.root

# %%
name_data = 'data_KPiPi_constr'
var = 'B0_M_Tau_Pi12pip'
var_constr = 'Dst_constr_B0_M_Tau_Pi12pip'
low = 4300
high = 5350

# %%
df = add_constr_Dst(df, var)

# %% [markdown]
# $\Delta M$ is already cut: $0.143\ GeV<\Delta M<0.148\ GeV$

# %%
df['Delta_M'] =df['Dst_M']-df['D0_M']
print(len(df['Delta_M']))
print(len(df.query('Delta_M>143 and Delta_M<148')))

h.plot_hist({name_data:df}, 'Delta_M','$\Delta M$', 'GeV/$c^2$', n_bins = 100, name_folder = name_data, colors='black', mode_hist=True,
           pos_text_LHC='left')
# Out:
# 32409
# 32409
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_KPiPi_constr/Delta_M_data_KPiPi_constr
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='$\\Delta M$ [GeV/$c^2$]', ylabel='Candidates / (0.03 GeV/$c^2$)'>)

# %%
h.plot_hist_particle({name_data:df}, 'Dst_M', n_bins = 100, name_folder = name_data, colors='black', mode_hist=False,
           pos_text_LHC='right')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_KPiPi_constr/Dst_M_data_KPiPi_constr
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='$m$($D^*$) [MeV/$c^2$]', ylabel='Candidates / (2 MeV/$c^2$)'>)

# %% [markdown]
# ## Plot 1D histograms

# %%
h.plot_hist_particle({name_data:df}, var, n_bins = 100, name_folder = name_data, colors='black', mode_hist=False,
                      low=low, high=high, pos_text_LHC='left')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_KPiPi_constr/B0_M_Tau_Pi12pip_data_KPiPi_constr
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='m($D^{*}3\\pi$) [GeV/$c^2$]', ylabel='Candidates / (1e+01 GeV/$c^2$)'>)

# %%
h.plot_hist_particle({name_data:df}, var_constr, n_bins = 100, name_folder = name_data, colors='black', 
                     mode_hist=False, low=low, high=high, pos_text_LHC='left')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_KPiPi_constr/Dst_constr_B0_M_Tau_Pi12pip_data_KPiPi_constr
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='m($B^0|m(D_s)$=2010.26 MeV/$c^2$) [GeV/$c^2$]', ylabel='Candidates / (1e+01 GeV/$c^2$)'>)

# %%
df_constr = pd.DataFrame()
df_constr[var] = df[var_constr]
fig, ax = h.plot_hist_particle({'$B^0\\to D^* K\pi\pi$':df, '$B^0\\to D^*\pi\pi$, $m(D^*)=m(D^*)_{PDG}$':df_constr}, var,
                     colors= ['orange', 'magenta'],
                     n_bins = 100, name_folder = name_data, 
                     mode_hist=True, low=low, high=high, save_fig=False, density=False)


pt.set_text_LHCb(ax, x=0.10, y=0.70, ha='left')
pt.save_file(fig, name_file=var_constr + '_' + name_data, name_folder=name_data)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_KPiPi_constr/Dst_constr_B0_M_Tau_Pi12pip_data_KPiPi_constr

# %% [markdown]
# ## Two opposed Crystall ball Fit

# %%
obs = zfit.Space("x", limits=(low, high))
# Out:
# The history saving thread hit an unexpected error (OperationalError('unable to open database file')).History will not be written to the database.

# %%
# fraction   0.8875     +/-   0.014       False
# alphaL     0.2414     +/-   0.014       False
# muL          5215     +/-    0.91       False
# nL          4.397     +/-    0.24       False
# sigmaL       19.2     +/-    0.61       False
# alphaR     -3.386     +/-    0.23       False
# muR          5183     +/-       3       False
# nR            0.1     +/-  0.0042       False
# sigmaR      39.41     +/-     1.5       False

muL = zfit.Parameter("muL", 5215, 5210, 5230)
muR = zfit.Parameter("muR", 5180, 5160, 5200)

sigmaL = zfit.Parameter("sigmaL", 20, 10., 50.)
sigmaR = zfit.Parameter("sigmaR", 40, 10., 50.)

alphaL = zfit.Parameter("alphaL", 0.3, 0.01, 2.)
alphaR = zfit.Parameter("alphaR", -1.8, -5., -0.1)

nL = zfit.Parameter("nL", 4.4, 0.1, 10.)
nR = zfit.Parameter("nR", 45., 0.0001, 60.)

frac = zfit.Parameter("fraction", 0.9, 0.1, 1.) # fraction between L and R

# %%
name_params = {
    'muL':'$\\mu_L$',
    'sigmaL':'$\\sigma_L$',
    'muR':'$\\mu_R$',
    'sigmaR':'$\\sigma_R$',
    'alphaL':'$\\alpha_L$',
    'alphaR':'$\\alpha_R$',
    'nL':'$n_L$',
    'nR':'$n_R$',
}

# %%
# doubleCB = zfit.pdf.DoubleCB(mu, sigma, alphaL, alphaR, nL, nR, obs=obs)

crystalBallL = zfit.pdf.CrystalBall(muL, sigmaL, alphaL, nL, obs=obs)
crystalBallR = zfit.pdf.CrystalBall(muR, sigmaR, alphaR, nR, obs=obs)
# gaussianR = zfit.pdf.Gauss(muR, sigmaR, obs=obs)

model = zfit.pdf.SumPDF([crystalBallL, crystalBallR], fracs=frac) # crystalBallR is multiplied by fracs

data = zfit.Data.from_pandas(df[var_constr],obs=obs)

# %%
result, params = launch_fit(model, data) # I performed 2 fits for the last fit to converge ...
result, params = launch_fit(model, data) 
result, params = launch_fit(model, data)
# Out:
# ------------------------------------------------------------------
# | FCN = 1.888e+05               |     Ncalls=599 (599 total)     |
# | EDM = 0.000845 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name        value    minuit_hesse    at limit
# --------  -------  --------------  ----------
# fraction   0.8878     +/-   0.015       False
# alphaL     0.2414     +/-   0.014       False
# muL          5215     +/-    0.92       False
# nL          4.394     +/-    0.22       False
# sigmaL       19.2     +/-    0.65       False
# alphaR     -2.475     +/-     0.4       False
# muR          5183     +/-     3.1       False
# nR          59.95     +/-     1.7       False
# sigmaR      39.37     +/-     1.8       False
# ------------------------------------------------------------------
# | FCN = 1.887e+05               |     Ncalls=403 (403 total)     |
# | EDM = 0.0101 (Goal: 0.001)    |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name        value    minuit_hesse    at limit
# --------  -------  --------------  ----------
# fraction   0.8875     +/-   0.014       False
# alphaL     0.2414     +/-   0.014       False
# muL          5215     +/-     0.9       False
# nL          4.398     +/-    0.23       False
# sigmaL       19.2     +/-     0.6       False
# alphaR     -3.379     +/-    0.26       False
# muR          5183     +/-     2.9       False
# nR         0.1003     +/-   0.035       False
# sigmaR      39.41     +/-     1.5       False
# ------------------------------------------------------------------
# | FCN = 1.887e+05               |     Ncalls=168 (168 total)     |
# | EDM = 0.00748 (Goal: 0.001)   |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name        value    minuit_hesse    at limit
# --------  -------  --------------  ----------
# fraction   0.8875     +/-   0.014       False
# alphaL     0.2414     +/-   0.014       False
# muL          5215     +/-    0.91       False
# nL          4.397     +/-    0.24       False
# sigmaL       19.2     +/-    0.61       False
# alphaR     -3.386     +/-    0.23       False
# muR          5183     +/-       3       False
# nR            0.1     +/-  0.0042       False
# sigmaR      39.41     +/-     1.5       False
# Info: VariableMetricBuilder: Stop the minimization - reached machine accuracy limit
# Info in Edm is smaller than machine accuracy : machineLimit = 0.0112503
# Info in Current  Edm is : edm = 0.0100681
# Info in Required Edm is : edmval = 0.001
# Info in VariableMetricBuilder: INVALID function minimum - edm is above tolerance, : edm = 0.0100681
# Info in VariableMetricBuilder: Required tolerance  is 10 x edmval  : edmval = 0.001
# Info: VariableMetricBuilder: Stop the minimization - reached machine accuracy limit
# Info in Edm is smaller than machine accuracy : machineLimit = 0.0112503
# Info in Current  Edm is : edm = 0.00747869
# Info in Required Edm is : edmval = 0.001

# %%
plot_hist_fit_particle(df, var_constr, models = [model, crystalBallL, crystalBallR], obs=obs, n_bins = 100,mode_hist = False,
                       name_folder = name_data, type_models= 'mss', loc_res='lower left',
                       name_data = name_data, params=params, name_params=name_params, show_chi2=True)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/plot/fit.py:501: UserWarning: The function <function Space.limits at 0x7fae67196680> may does not return the actual area/limits but rather the rectangular limits. <zfit Space obs=('x',), axes=None, limits=(array([[4300.]]), array([[5350.]]))> can also have functional limits that are arbitrarily defined and lay inside the rect_limits. To test if a value is inside, use `inside` or `filter`.
#   low = float(obs.limits[0])
# /afs/cern.ch/user/c/correian/bd2dst3pi/scripts/plot/fit.py:32: UserWarning: The function <function Space.area at 0x7fae6719da70> may does not return the actual area/limits but rather the rectangular limits. <zfit Space obs=('x',), axes=None, limits=(array([[4300.]]), array([[5350.]]))> can also have functional limits that are arbitrarily defined and lay inside the rect_limits. To test if a value is inside, use `inside` or `filter`.
#   return counts.sum() * obs.area() / n_bins
# Number of d.o.f. in the model:  9
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/table.py in draw(self, renderer)
#     404
#     405         for key in sorted(self._cells):
# --> 406             self._cells[key].draw(renderer)
#     407
#     408         renderer.close_group('table')
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/table.py in draw(self, renderer)
#     140         # position the text
#     141         self._set_text_position(renderer)
# --> 142         self._text.draw(renderer)
#     143         self.stale = False
#     144
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     679
#     680         with _wrap_text(self) as textobj:
# --> 681             bbox, info, descent = textobj._get_layout(renderer)
#     682             trans = textobj.get_transform()
#     683
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     294             if clean_line:
#     295                 w, h, d = renderer.get_text_width_height_descent(
# --> 296                     clean_line, self._fontproperties, ismath=ismath)
#     297             else:
#     298                 w = h = d = 0
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     226             fontsize = prop.get_size_in_points()
#     227             w, h, d = texmanager.get_text_width_height_descent(
# --> 228                 s, fontsize, renderer=self)
#     229             return w, h, d
#     230
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     305         dvifile = '%s.dvi' % basefile
#     306         if not os.path.exists(dvifile):
# --> 307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
#     309                 self._run_checked_subprocess(
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/texmanager.py in make_tex(self, tex, fontsize)
#     224 \end{document}
#     225 """ % (self._get_preamble(), fontsize, fontsize * 1.25, fontcmd % tex),
# --> 226             encoding='utf-8')
#     227
#     228         return texfile
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/pathlib.py in write_text(self, data, encoding, errors)
#    1238             raise TypeError('data must be str, not %s' %
#    1239                             data.__class__.__name__)
# -> 1240         with self.open(mode='w', encoding=encoding, errors=errors) as f:
#    1241             return f.write(data)
#    1242
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1206             self._raise_closed()
#    1207         return io.open(self, mode, buffering, encoding, errors, newline,
# -> 1208                        opener=self._opener)
#    1209
#    1210     def read_bytes(self):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/pathlib.py in _opener(self, name, flags, mode)
#    1061     def _opener(self, name, flags, mode=0o666):
#    1062         # A stub for the opener argument to built-in open()
# -> 1063         return self._accessor.open(self, flags, mode)
#    1064
#    1065     def _raw_open(self, flags, mode=0o777):
#
# TimeoutError: [Errno 110] Connection timed out: '/afs/cern.ch/user/c/correian/.cache/matplotlib/tex.cache/0c78a85231857bdafb6322b6fd3eefa9.tex'
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# <ipython-input-10-bfd800706a46> in <module>
#       1 plot_hist_fit_particle(df, var_constr, models = [model, crystalBallL, crystalBallR], obs=obs, n_bins = 100,mode_hist = False,
#       2                        name_folder = name_data, type_models= 'mss', loc_res='lower left',
# ----> 3                        name_data = name_data, params=params, name_params=name_params, show_chi2=True)
#
# ~/bd2dst3pi/scripts/plot/fit.py in plot_hist_fit_particle(df, variable, cut_BDT, **kwargs)
#     597         kwargs['name_folder'] = kwargs['name_data']
#     598
# --> 599     return plot_hist_fit(df, variable, name_var=name_variable, unit_var=unit_var, **kwargs)
#
# ~/bd2dst3pi/scripts/plot/fit.py in plot_hist_fit(df, variable, name_var, unit_var, models, obs, n_bins, color, name_models, type_models, mode_hist, linewidth, colors, name_data_title, title, fontsize_leg, name_file, name_folder, name_data, show_chi2, params, name_params, colWidths, fontsize_res, loc_res, loc_leg, weights, save_fig, pos_text_LHC)
#     550     plt.show()
#     551     if save_fig:
# --> 552         pt.save_file(fig, name_file,name_folder,f'{variable}_{name_data}_fit')
#     553
#     554     return fig, ax
#
# ~/bd2dst3pi/scripts/plot/tool.py in save_file(fig, name_file, name_folder, alt_name_file, directory)
#      52     path = op.join(directory, f"{name_file}")
#      53     #Save the plot as a PDF document into our PLOTS folder (output/plots as defined in bd2dst3pi/locations.py)
# ---> 54     fig.savefig(path + '.pdf', dpi=600, bbox_inches="tight")
#      55     fig.savefig(path + '.jpg', dpi=600, bbox_inches="tight")
#      56     print(path)
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1862             self.patch.draw(renderer)
#    1863             mimage._draw_list_compositing_images(
# -> 1864                 renderer, self, artists, self.suppressComposite)
#    1865
#    1866             renderer.close_group('figure')
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/cbook/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/table.py in draw(self, renderer)
#     404
#     405         for key in sorted(self._cells):
# --> 406             self._cells[key].draw(renderer)
#     407
#     408         renderer.close_group('table')
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/table.py in draw(self, renderer)
#     140         # position the text
#     141         self._set_text_position(renderer)
# --> 142         self._text.draw(renderer)
#     143         self.stale = False
#     144
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/text.py in draw(self, renderer)
#     679
#     680         with _wrap_text(self) as textobj:
# --> 681             bbox, info, descent = textobj._get_layout(renderer)
#     682             trans = textobj.get_transform()
#     683
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     287         _, lp_h, lp_d = renderer.get_text_width_height_descent(
#     288             "lp", self._fontproperties,
# --> 289             ismath="TeX" if self.get_usetex() else False)
#     290         min_dy = (lp_h - lp_d) * self._linespacing
#     291
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/backends/_backend_pdf_ps.py in get_text_width_height_descent(self, s, prop, ismath)
#      85             fontsize = prop.get_size_in_points()
#      86             w, h, d = texmanager.get_text_width_height_descent(
# ---> 87                 s, fontsize, renderer=self)
#      88             return w, h, d
#      89         elif ismath:
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/texmanager.py in get_text_width_height_descent(self, tex, fontsize, renderer)
#     421         else:
#     422             # use dviread.
# --> 423             dvifile = self.make_dvi(tex, fontsize)
#     424             with dviread.Dvi(dvifile, 72 * dpi_fraction) as dvi:
#     425                 page, = dvi
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/texmanager.py in make_dvi(self, tex, fontsize)
#     305         dvifile = '%s.dvi' % basefile
#     306         if not os.path.exists(dvifile):
# --> 307             texfile = self.make_tex(tex, fontsize)
#     308             with cbook._lock_path(texfile):
#     309                 self._run_checked_subprocess(
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/matplotlib/texmanager.py in make_tex(self, tex, fontsize)
#     224 \end{document}
#     225 """ % (self._get_preamble(), fontsize, fontsize * 1.25, fontcmd % tex),
# --> 226             encoding='utf-8')
#     227
#     228         return texfile
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/pathlib.py in write_text(self, data, encoding, errors)
#    1238             raise TypeError('data must be str, not %s' %
#    1239                             data.__class__.__name__)
# -> 1240         with self.open(mode='w', encoding=encoding, errors=errors) as f:
#    1241             return f.write(data)
#    1242
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/pathlib.py in open(self, mode, buffering, encoding, errors, newline)
#    1206             self._raise_closed()
#    1207         return io.open(self, mode, buffering, encoding, errors, newline,
# -> 1208                        opener=self._opener)
#    1209
#    1210     def read_bytes(self):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/pathlib.py in _opener(self, name, flags, mode)
#    1061     def _opener(self, name, flags, mode=0o666):
#    1062         # A stub for the opener argument to built-in open()
# -> 1063         return self._accessor.open(self, flags, mode)
#    1064
#    1065     def _raw_open(self, flags, mode=0o777):
#
# TimeoutError: [Errno 110] Connection timed out: '/afs/cern.ch/user/c/correian/.cache/matplotlib/tex.cache/c99befe9a1c97fca3d27815aae7b178b.tex'

# %%
fig, ax = plot_hist_fit_particle(df, var, models = [model, crystalBallL, crystalBallR], obs=obs, n_bins = 100,mode_hist = False,
                       name_folder = name_data, type_models= 'mss', loc_res='lower left',
                       name_data = name_data+'_chi2', save_fig=False,
                       frac = float(frac))   
pt.set_text_LHCb(ax, x=0.10, y=0.70, ha='left')
pt.save_file(fig, name_file=var_constr + '_' + name_data +'_fit', name_folder=name_data)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/data_KPiPi_2/B0_M_Tau_Pi12pip_data_KPiPi_2_chi2_fit.pdf

# %%
save_params(params, name_data, True)
# Out:
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/data_KPiPi_2_params.json
