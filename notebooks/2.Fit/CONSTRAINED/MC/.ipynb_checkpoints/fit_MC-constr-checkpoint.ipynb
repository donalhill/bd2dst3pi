# %% [markdown]
# # `MC_constr_opposedCB_sharedMean`
# # Fit of `B0_M` with the $D^*$-constrained MC data
# - cut on $\Delta M$ : $143 MeV < \Delta M < 148 MeV$ on the MC data
# - Sum of two CB with shared mean
# - Constrained `Dst_M`
#
# Constrained data test in `4.Plots/3_constrained_mass`

# %% [markdown]
# ## Libraries

# %%
import numpy as np
import zfit

from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets


import sys
sys.path.append(loc.SCRIPTS)
from load_save_data import load_data, add_constr_Dst
import plot.histogram as h
from plot.fit import plot_hist_fit_particle
from fit import launch_fit, save_params, sum_crystalball
# Out:
# Welcome to JupyROOT 6.22/02

# %% [markdown]
# ## Retrieve data

# %%
name_data = 'MC_constr_opposedCB_sharedMean' # MC corrected with the correct range
name_var = 'Dst_constr_B0_M'

# %%
df_MC = load_data(years,magnets,type_data = 'MC',vars = ['B0_M', 'Dst_M'],cut_DeltaM = True)
df_MC = add_constr_Dst(df_MC)
# Out:
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_up_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2015_down_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2016_up_Sim09e-ReDecay01.root
# /eos/lhcb/wg/semileptonic/RXcHad/B02Dsttaunu/Run2/ntuples//norm/Bd_Dst3pi/Bd_Dst3pi_11266018_2016_down_Sim09e-ReDecay01.root
# cut on DeltaM has removed 0 over 23724 events

# %% [markdown]
# ## Plot 1D histograms

# %%
h.plot_hist_particle({name_data:df_MC}, name_var, n_bins = 100, colors='black', pos_text_LHC='right')
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/Dst_constr_B0_M_MC_constr_opposedCB_sharedMean
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='$m$($B^0|m(D_s)$=2010.26 MeV/$c^2$) [MeV/$c^2$]', ylabel='Candidates / (3 MeV/$c^2$)'>)

# %% [markdown]
# ## Double CB Fit of `B0_M` of the MC data

# %%
low = 5150.
high = 5400.
obs = zfit.Space("x", limits=(low, high))

# %%
# DOUBLE CB
# mu_MC = zfit.Parameter("mu_MC", 5280., 5250., 5300.)
# sigma_MC = zfit.Parameter("sigma_MC", 20., 10., 60.)


# alphaL_MC = zfit.Parameter("alphaL_MC", 2., 0.1, 5.)
# alphaR_MC = zfit.Parameter("alphaR_MC", 2., 0.1, 5.)
# nL_MC = zfit.Parameter("nL_MC", 2., 0.01, 10.)
# nR_MC = zfit.Parameter("nR_MC", 2., 0.01, 10.)
# frac_MC = zfit.Parameter("frac_MC", 0.5, 0.1, 1.)


# # Sum of two CB of opposite tails with shared mean
# # frac_MC     0.9481     +/-  0.0081       False
# # alphaL_MC    1.903     +/-   0.067       False
# # mu_MC         5280     +/-    0.11       False
# # nL_MC        1.541     +/-    0.14       False
# # sigmaL_MC    12.25     +/-    0.11       False
# # alphaR_MC    1.729     +/-    0.22       False
# # nR_MC        2.691     +/-     3.6       False
# # sigmaR_MC    35.56     +/-     2.2       False

mu_MC = zfit.Parameter("mu_MC", 5280., 5250., 5300.)
sigmaL_MC = zfit.Parameter("sigmaL_MC", 20., 10., 60.)
sigmaR_MC = zfit.Parameter("sigmaR_MC", 20., 10., 60.)

alphaL_MC = zfit.Parameter("alphaL_MC", 2., 0.1, 5.)
alphaR_MC = zfit.Parameter("alphaR_MC", -2., -5., -0.1)
nL_MC = zfit.Parameter("nL_MC", 2., 0.01, 10.)
nR_MC = zfit.Parameter("nR_MC", 2., 0.01, 50.)
frac_MC = zfit.Parameter("frac_MC", 0.5, 0.01, 1.)


# Sum of two CB of opposite tails
# frac_MC     0.9481     +/-  0.0081       False
# alphaL_MC    1.903     +/-   0.067       False
# mu_MC         5280     +/-    0.11       False
# nL_MC        1.541     +/-    0.14       False
# sigmaL_MC    12.25     +/-    0.11       False
# alphaR_MC    1.729     +/-    0.22       False
# nR_MC        2.691     +/-     3.6       False
# sigmaR_MC    35.56     +/-     2.2       False

# muL_MC = zfit.Parameter("muL_MC", 5280., 5250., 5300.)
# muR_MC = zfit.Parameter("muR_MC", 5280., 5250., 5300.)
# sigmaL_MC = zfit.Parameter("sigmaL_MC", 20., 10., 60.)
# sigmaR_MC = zfit.Parameter("sigmaR_MC", 20., 1., 60.)

# alphaL_MC = zfit.Parameter("alphaL_MC", 2., 0.1, 5.)
# alphaR_MC = zfit.Parameter("alphaR_MC", -2., -5., -0.1)
# nL_MC = zfit.Parameter("nL_MC", 2., 0.01, 10.)
# nR_MC = zfit.Parameter("nR_MC", 2., 0.01, 10.)
# frac_MC = zfit.Parameter("frac_MC", 0.5, 0.1, 1.)

# %%
name_params = {
    'mu_MC':'$\mu$',
    'muL_MC':'$\\mu_L$',
    'muR_MC':'$\\mu_R$',
    'sigma_MC':'$\sigma$',
    'sigmaL_MC':'$\\sigma_L$',
    'sigmaR_MC':'$\\sigma_R$',
    'alphaL_MC':'$\\alpha_L$',
    'alphaR_MC':'$\\alpha_R$',
    'nL_MC':'$n_L$',
    'nR_MC':'$n_R$',
}

# %%
# doubleCB_MC = zfit.pdf.DoubleCB(mu_MC, sigma_MC, alphaL_MC, alphaR_MC, nL_MC, nR_MC, obs=obs)
data_MC = zfit.Data.from_pandas(df_MC[name_var],obs=obs)

model_S, crystalBallL_S, crystalBallR_S = sum_crystalball(mu_MC, mu_MC,
                                                          sigmaL_MC, sigmaR_MC,
                                                          frac_MC, obs,                                                          
                                                          alphaL_MC, alphaR_MC, 
                                                          nL_MC, nR_MC
                                                         )

# model_S, crystalBallL_S, crystalBallR_S = sum_crystalball(muL_MC, muR_MC,
#                                                           sigmaL_MC, sigmaR_MC,
#                                                           frac_MC, obs,                                                          
#                                                           alphaL_MC, alphaR_MC, 
#                                                           nL_MC, nR_MC
#                                                          )

# %%
# result, params = launch_fit(doubleCB_MC, data_MC)
# result, params = launch_fit(doubleCB_MC, data_MC)
# result, params = launch_fit(doubleCB_MC, data_MC)
result, params = launch_fit(model_S, data_MC)
result, params = launch_fit(model_S, data_MC)
result, params = launch_fit(model_S, data_MC)
# Out:
# ------------------------------------------------------------------
# | FCN = 9.928e+04               |     Ncalls=702 (702 total)     |
# | EDM = 4.14e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name         value    minuit_hesse    at limit
# ---------  -------  --------------  ----------
# frac_MC     0.6265     +/-    0.31       False
# alphaL_MC    1.434     +/-    0.43       False
# mu_MC         5280     +/-    0.18       False
# nL_MC        1.957     +/-    0.69       False
# sigmaL_MC    11.87     +/-     1.7       False
# alphaR_MC   -1.424     +/-    0.31       False
# nR_MC         5.84     +/-     4.3       False
# sigmaR_MC    12.43     +/-     3.9       False
# ------------------------------------------------------------------
# | FCN = 9.928e+04               |     Ncalls=126 (126 total)     |
# | EDM = 9.16e-06 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name         value    minuit_hesse    at limit
# ---------  -------  --------------  ----------
# frac_MC     0.6266     +/-    0.15       False
# alphaL_MC    1.434     +/-     0.2       False
# mu_MC         5280     +/-    0.13       False
# nL_MC        1.957     +/-    0.35       False
# sigmaL_MC    11.87     +/-    0.85       False
# alphaR_MC   -1.424     +/-    0.19       False
# nR_MC         5.84     +/-     2.4       False
# sigmaR_MC    12.43     +/-     1.8       False
# ------------------------------------------------------------------
# | FCN = 9.928e+04               |     Ncalls=128 (128 total)     |
# | EDM = 6.62e-06 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name         value    minuit_hesse    at limit
# ---------  -------  --------------  ----------
# frac_MC     0.6265     +/-    0.15       False
# alphaL_MC    1.434     +/-    0.21       False
# mu_MC         5280     +/-    0.13       False
# nL_MC        1.957     +/-    0.35       False
# sigmaL_MC    11.87     +/-    0.85       False
# alphaR_MC   -1.424     +/-    0.19       False
# nR_MC        5.841     +/-     2.4       False
# sigmaR_MC    12.43     +/-     1.8       False
# Info: VariableMetricBuilder: Tolerance is not sufficient, continue the minimization
# Info in Current  Edm is : edm = 0.0233326
# Info in Required Edm is : edmval = 0.001

# %%
# plot_hist_fit_particle(df_MC,name_var, models = doubleCB_MC, obs=obs, n_bins = 80, mode_hist = False,
#               name_data = name_data, params=params, name_params=name_params, show_chi2=True)
plot_hist_fit_particle(df_MC,name_var, models = [model_S, crystalBallL_S, crystalBallR_S], 
                       name_models=["","",""],
                       obs=obs, n_bins = 80, mode_hist = False,
              name_data = name_data, params=params, name_params=name_params, show_chi2=True)
# Out:
# Number of d.o.f. in the model:  8
# Reduced chi2:  1.5202203782274362
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/MC_constr_opposedCB_sharedMean/Dst_constr_B0_M_MC_constr_opposedCB_sharedMean_fit
# (<Figure size 864x720 with 2 Axes>,
#  <AxesSubplot:xlabel='$m$($B^0|m(D_s)$=2010.26 MeV/$c^2$) [MeV/$c^2$]', ylabel='Candidates / (3 MeV/$c^2$)'>,
#  <AxesSubplot:xlabel='(reduced $\\chi^2$=1.52)', ylabel='residuals / $\\sigma$'>)

# %%
plot_hist_fit_particle(df_MC,name_var, models = [model_S, crystalBallL_S, crystalBallR_S], 
                       name_models=['', '', ''],
                       type_models= 'mss',
                       obs=obs, n_bins = 80, mode_hist = False,
                       name_data = name_data, pos_text_LHC='right')
# Out:
# Number of d.o.f. in the model:  8
# Reduced chi2:  1.5202203782274362
# findfont: Font family ['serif'] not found. Falling back to DejaVu Sans.
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/MC_constr_opposedCB_sharedMean/Dst_constr_B0_M_MC_constr_opposedCB_sharedMean_fit
# (<Figure size 864x720 with 2 Axes>,
#  <AxesSubplot:xlabel='$m$($B^0|m(D_s)$=2010.26 MeV/$c^2$) [MeV/$c^2$]', ylabel='Candidates / (3 MeV/$c^2$)'>,
#  <AxesSubplot:ylabel='residuals / $\\sigma$'>)

# %%
save_params(params, name_data, True, name_folder='MC')
# Out:
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/MC/MC_constr_opposedCB_sharedMean_params.json
