# %% [markdown]
# # Compute the sWeights
# For a given cut on the `BDT` value, with the starting value of the fit chosen as the result of the previous fit, specified by `cut_BDT_ref`, manually chosen to be `cut_BDT - 0.05`.
# 1. Fit on $m(3\pi)$ for $|m(3\pi) - 1968|<50$
#     - Signal shape: Gaussian
#     - Background shape: Exponential
# 2. Compute the associated probability and sWeights, save the sWeights in a Pickle file.
# 3. Plot some interesting things for checking
# 4. Save the full dataframe in a root file. It will be the input of `fit_all_data_V8_2_files_BDTs_recomputed_sWeights.ipynb`.
#
# Thanks to the fit, we get
# - $f_g(m)$, the signal Ds PDF
# - $f_e(m)$, the background Ds PDF
# Besides, our dataset is given by a list of events, each event is characterised by $m_{3\pi})$
#
# We define the probability of the event $e$ being a $D_s$ by:
# $$P\left(e = D_s\right)=\frac{f_g(m_{e, 3\pi})}{\sum_{event\ k}{\left(f_g(m_{k,3\pi})+f_e(m_{k, 3\pi})\right)}}$$
#
# From this probabily, the sWeights can be computed.
#
# The saved root file is already cut on the `BDT` output, and has a new column `sWeight`. The root files are saved in `output/root/common/`

# %%
import zfit
import json
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import pickle
from hep_ml import splot
import timeit
from scipy.stats import pearsonr

from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets

import sys
sys.path.append(loc.SCRIPTS)
import functions as fct
from fit import launch_fit, save_params, plot_hist_fit, plot_hist_fit_particle

# %% [markdown]
# ## INIT

# %% [markdown]
# ### Retrieve data

# %%
# load_data does the cut on DeltaM and tau_M (around m(Ds)).
df_common_Ds = fct.load_data(years, magnets, type_data='common', vars=['B0_M', 'tau_M', 'BDT'],
                            cut_DeltaM=True, cut_tau_Ds=True)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs.root

# %%
name_data = 'all_common_cutDeltaM_Ds23pi_V8'

# %% [markdown]
# ### BDT cuts

# %% [markdown]
# Reference fit whose results are taken as the starting values of the new fit.
# It is specified by `cut_BDT_ref`, the cut on the `BDT` output.
# If None, the reference fit is the one performed without any cut on the `BDT` output.

# %%
l_BDT = []
l_BDT_ref = []
#starting_value = -0.4
starting_value = 0.2
end_value      =  0.4
step           = 0.025


value = starting_value
while value != end_value:
    if round(value%0.05, 3) != 0: # value not a multiple of 0.05
        if value==0:
            value = 0
        l_BDT.append(value)
    
        if value <= -0.2:
            l_BDT_ref.append(None)
        else:
            BDT_ref = np.round(l_BDT[-1]-0.025,4)
            if BDT_ref==0:
                BDT_ref=0
            l_BDT_ref.append(BDT_ref)
    
    value = np.round(value + step, 3)

# %% [markdown]
# ### Range of the variable

# %%
size_tau_M = 50.
mean_tau_M = 1969.
low_tau_M = mean_tau_M - size_tau_M
high_tau_M = mean_tau_M + size_tau_M

# %% [markdown]
# ## LOOP

# %%
for cut_BDT, cut_BDT_ref in zip(l_BDT, l_BDT_ref):
    ## CUT ON BDT -------------------------------------------------------
    k = str(cut_BDT)
    df_Ds = df_common_Ds.query(f"BDT > {cut_BDT}")
    
    print(f"================================ cut_BDT = {k} ================================")
    print(f"cut_BDT_ref = {cut_BDT_ref}")
    
    ## REFERENCE BDT CUT ------------------------------------------------
    if cut_BDT_ref is None:
        with open(f'{loc.JSON}/{name_data}_params.json', 'r') as f:
            params_r = json.load(f)   
    else:
        with open(f'{loc.JSON}/{name_data}_BDT{cut_BDT_ref}_params.json', 'r') as f:
            params_recup = json.load(f)

        params_r = format_previous_params(params_recup)
    
    ### HISTOGRAM --------------------------------------------------------
    fct.plot_hist_particle({name_data:df_Ds},'tau_M', cut_BDT=cut_BDT,
              n_bins = 100, mode_hist = False, colors='black')
    
    ### FITTING ----------------------------------------------------------
    ## Starting point ........................
    n_events_tau_M = len(df_Ds)
    initial_values_tau = {
        'mu_tau': {
            'value' : params_r['mu_tau'],
            'low': 1965.,
            'high': 1975.,     
        },
        'sigma_tau': {
            'value' : params_r['sigma_tau'],
            'low': 5.,
            'high': 15.,
        },
        'n_bkg_tau': {
            'value' : params_r['n_bkg_tau'],
            'low': 0,
            'high': n_events_tau_M,  
        },
        'n_sig_tau': {
            'value' : params_r['n_sig_tau'],
            'low': 0,
            'high': n_events_tau_M,  
        },
        'lambda_tau': {
            'value' : params_r['lambda_tau'],
            'low': -0.01,
            'high': -0.000001  
        }
    }
    
    ## Parameters .............................
    obs_tau = zfit.Space("x", limits=(low_tau_M, high_tau_M))
    zparams_tau = {}

    for var_tau in initial_values_tau.keys():
        zparams_tau[var_tau] = zfit.Parameter(f"{var_tau}|BDT{cut_BDT}", initial_values_tau[var_tau]['value'], 
                                         initial_values_tau[var_tau]['low'], initial_values_tau[var_tau]['high'])
    ## Name of the variables ..................
    name_params_tau = {
        # Signal
        f'mu_tau|BDT{cut_BDT}'     :'$\mu_{S}$',
        f'sigma_tau|BDT{cut_BDT}'  :'$\sigma_{S}$',
        f'n_sig_tau|BDT{cut_BDT}'  :'$n_{S}$',
        # Combinatorial background
        f'n_bkg_tau|BDT{cut_BDT}'  :'$n_{B,c}$',
        f'lambda_tau|BDT{cut_BDT}' :'$\\lambda_{B,c}$',
    }
    
    ## PDFs ...................................
    gaussian_tau = zfit.pdf.Gauss(zparams_tau["mu_tau"],zparams_tau["sigma_tau"],obs=obs_tau)
    exponential_tau = zfit.pdf.Exponential(zparams_tau["lambda_tau"], obs=obs_tau)

    gaussian_ext_tau = gaussian_tau.create_extended(zparams_tau["n_sig_tau"])
    exp_ext_tau = exponential_tau.create_extended(zparams_tau["n_bkg_tau"])
    model_tau = zfit.pdf.SumPDF([gaussian_ext_tau, exp_ext_tau]) # gauss is folded by frac

    data_tau = zfit.Data.from_pandas(df_Ds['tau_M'],obs=obs_tau)
    
    ## Launch the fit .........................
    start = timeit.default_timer()
    result_tau, params_tau = launch_fit(model_tau, data_tau, extended=True)
    result_tau, params_tau = launch_fit(model_tau, data_tau, extended=True)
    stop = timeit.default_timer()
    print('Time to do the fit: ', stop - start) 
    
    ## Result of the fit ......................
    plot_hist_fit_particle(df_Ds,'tau_M',models = [model_tau,gaussian_ext_tau,exp_ext_tau], 
                       name_models = ["", '$D_S \\to 3\pi$','(combinatorial)'], 
                       colors = ['b','r','y'], cut_BDT=cut_BDT,
                       obs=obs_tau, n_bins = 100,mode_hist = False, name_data=name_data, 
                      params=params_tau,name_params=name_params_tau, fontsize_leg=15.)
    ## Correlation ...........................
    corr_B0_M_tau_M = pearsonr(df_Ds['tau_M'], df_Ds['B0_M'])[0]
    print(corr_B0_M_tau_M)
    
    ## Save the result .......................
    save_params(params_tau,name_data + f'_BDT{cut_BDT}', True, {'corr_B0_M_tau_M': corr_B0_M_tau_M})
    
    ### SWEIGHTS -------------------------------------------------------------------
    ## Computation ...........................
    
    # Probability that the candidate is actually a Ds particle.
    mass = df_Ds['tau_M']
    probs = pd.DataFrame(dict(sig=gaussian_ext_tau.pdf(mass), bkg=exp_ext_tau.pdf(mass)))
    probs = probs.div(probs.sum(axis=1), axis=0) # normalisation
    # sWeights
    sWeights = splot.compute_sweights(probs)
    
    ## Analysis of the sWeights .............
    fig, ax = plt.subplots(figsize=(8,6))

    ax.plot(mass, probs.sig,'.', label='Signal')
    ax.plot(mass, probs.bkg,'.', label='Background')

    plt.xlim(low_tau_M, high_tau_M) 
    plt.xlabel('$m(3\pi)$',fontsize=20)
    plt.ylabel('Probability',fontsize=20)
    
    plt.show()
    plt.close()
    
    fig, ax = plt.subplots(figsize=(8,6))

    ax.plot(mass, sWeights.sig,'.', label='Signal')
    ax.plot(mass, sWeights.bkg,'.', label='Background')

    plt.xlim(low_tau_M, high_tau_M) 
    fct.fix_plot(ax, ymax=None)

    plt.xlabel('$m(3\pi)$',fontsize=20)
    plt.ylabel('sWeights',fontsize=20)

    ymin, ymax = ax.get_ylim()
    ax.set_ylim(ymin, ymax*1.1)

    plt.show()
    plt.close()
    
    ### Save the result ----------------------------------------------------------------
    fct.save_dataframe(sWeights, f'common_B0toDstDs_sWeights_BDT{cut_BDT}', 'sWeights', name_folder='common')
    df_Ds['sWeight'] = sWeights.sig.to_numpy()
    fct.save_dataframe(df_Ds, f'common_B0toDstDs_BDT{cut_BDT}', 'DecayTree', name_folder='common')
# Out:
# ================================ cut_BDT = 0.225 ================================
# cut_BDT_ref = 0.2
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/tau_M_all_common_cutDeltaM_Ds23pi_V8_BDT0.225.pdf
# ------------------------------------------------------------------
# | FCN = -9250                   |     Ncalls=110 (110 total)     |
# | EDM = 7.98e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                     value    minuit_hesse    at limit
# -------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.225        1863     +/-      60       False
# n_bkg_tau|BDT0.225        1471     +/-      57       False
# mu_tau|BDT0.225           1969     +/-     0.3       False
# sigma_tau|BDT0.225       9.483     +/-     0.3       False
# lambda_tau|BDT0.225  -0.005105     +/- 0.00097       False
# ------------------------------------------------------------------
# | FCN = -9250                   |      Ncalls=62 (62 total)      |
# | EDM = 4.53e-06 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                     value    minuit_hesse    at limit
# -------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.225        1863     +/-      60       False
# n_bkg_tau|BDT0.225        1471     +/-      57       False
# mu_tau|BDT0.225           1969     +/-     0.3       False
# sigma_tau|BDT0.225       9.482     +/-     0.3       False
# lambda_tau|BDT0.225  -0.005114     +/- 0.00097       False
# Time to do the fit:  2.199378497003636
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/all_common_cutDeltaM_Ds23pi_V8/tau_M_all_common_cutDeltaM_Ds23pi_V8_fit_BDT0.225.pdf
# 0.05916540117349892
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/all_common_cutDeltaM_Ds23pi_V8_BDT0.225_params.json
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_sWeights_BDT0.225.root
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_BDT0.225.root
# ================================ cut_BDT = 0.25 ================================
# cut_BDT_ref = 0.225
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/tau_M_all_common_cutDeltaM_Ds23pi_V8_BDT0.25.pdf
# ------------------------------------------------------------------
# | FCN = -6947                   |      Ncalls=94 (94 total)      |
# | EDM = 0.000364 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                    value    minuit_hesse    at limit
# ------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.25        1492     +/-      54       False
# n_bkg_tau|BDT0.25        1222     +/-      52       False
# mu_tau|BDT0.25           1969     +/-    0.34       False
# sigma_tau|BDT0.25       9.503     +/-    0.34       False
# lambda_tau|BDT0.25  -0.005266     +/-  0.0011       False
# ------------------------------------------------------------------
# | FCN = -6947                   |      Ncalls=64 (64 total)      |
# | EDM = 7.12e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                    value    minuit_hesse    at limit
# ------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.25        1492     +/-      55       False
# n_bkg_tau|BDT0.25        1222     +/-      52       False
# mu_tau|BDT0.25           1969     +/-    0.34       False
# sigma_tau|BDT0.25       9.509     +/-    0.34       False
# lambda_tau|BDT0.25  -0.005279     +/-  0.0011       False
# Time to do the fit:  2.2989087969981483
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/all_common_cutDeltaM_Ds23pi_V8/tau_M_all_common_cutDeltaM_Ds23pi_V8_fit_BDT0.25.pdf
# 0.05181163919936683
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/all_common_cutDeltaM_Ds23pi_V8_BDT0.25_params.json
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_sWeights_BDT0.25.root
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_BDT0.25.root
# ================================ cut_BDT = 0.275 ================================
# cut_BDT_ref = 0.25
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/tau_M_all_common_cutDeltaM_Ds23pi_V8_BDT0.275.pdf
# ------------------------------------------------------------------
# | FCN = -5099                   |     Ncalls=108 (108 total)     |
# | EDM = 8.12e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                     value    minuit_hesse    at limit
# -------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.275        1214     +/-      50       False
# n_bkg_tau|BDT0.275       962.7     +/-      47       False
# mu_tau|BDT0.275           1968     +/-    0.39       False
# sigma_tau|BDT0.275       9.667     +/-    0.39       False
# lambda_tau|BDT0.275  -0.005532     +/-  0.0012       False
# ------------------------------------------------------------------
# | FCN = -5099                   |      Ncalls=61 (61 total)      |
# | EDM = 7.02e-06 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                     value    minuit_hesse    at limit
# -------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.275        1214     +/-      50       False
# n_bkg_tau|BDT0.275       962.5     +/-      47       False
# mu_tau|BDT0.275           1968     +/-    0.39       False
# sigma_tau|BDT0.275       9.665     +/-    0.39       False
# lambda_tau|BDT0.275  -0.005537     +/-  0.0012       False
# Time to do the fit:  2.5617410839986405
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/all_common_cutDeltaM_Ds23pi_V8/tau_M_all_common_cutDeltaM_Ds23pi_V8_fit_BDT0.275.pdf
# 0.04934297755916347
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/all_common_cutDeltaM_Ds23pi_V8_BDT0.275_params.json
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_sWeights_BDT0.275.root
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_BDT0.275.root
# ================================ cut_BDT = 0.3 ================================
# cut_BDT_ref = 0.275
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/tau_M_all_common_cutDeltaM_Ds23pi_V8_BDT0.3.pdf
# ------------------------------------------------------------------
# | FCN = -3583                   |     Ncalls=107 (107 total)     |
# | EDM = 0.000119 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                   value    minuit_hesse    at limit
# -----------------  ---------  --------------  ----------
# n_sig_tau|BDT0.3       955.6     +/-      42       False
# n_bkg_tau|BDT0.3       743.5     +/-      40       False
# mu_tau|BDT0.3           1968     +/-    0.41       False
# sigma_tau|BDT0.3       9.343     +/-     0.4       False
# lambda_tau|BDT0.3  -0.005417     +/-  0.0014       False
# ------------------------------------------------------------------
# | FCN = -3583                   |      Ncalls=64 (64 total)      |
# | EDM = 3.33e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                   value    minuit_hesse    at limit
# -----------------  ---------  --------------  ----------
# n_sig_tau|BDT0.3       955.6     +/-      42       False
# n_bkg_tau|BDT0.3       743.3     +/-      40       False
# mu_tau|BDT0.3           1968     +/-    0.41       False
# sigma_tau|BDT0.3       9.346     +/-     0.4       False
# lambda_tau|BDT0.3  -0.005412     +/-  0.0014       False
# Time to do the fit:  2.7550711139992927
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/all_common_cutDeltaM_Ds23pi_V8/tau_M_all_common_cutDeltaM_Ds23pi_V8_fit_BDT0.3.pdf
# 0.05052735077804389
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/all_common_cutDeltaM_Ds23pi_V8_BDT0.3_params.json
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_sWeights_BDT0.3.root
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_BDT0.3.root
# ================================ cut_BDT = 0.325 ================================
# cut_BDT_ref = 0.3
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/tau_M_all_common_cutDeltaM_Ds23pi_V8_BDT0.325.pdf
# ------------------------------------------------------------------
# | FCN = -2412                   |     Ncalls=110 (110 total)     |
# | EDM = 0.000332 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                    value    minuit_hesse    at limit
# -------------------  --------  --------------  ----------
# n_sig_tau|BDT0.325      740.3     +/-      37       False
# n_bkg_tau|BDT0.325        559     +/-      34       False
# mu_tau|BDT0.325          1968     +/-    0.45       False
# sigma_tau|BDT0.325      9.074     +/-    0.43       False
# lambda_tau|BDT0.325  -0.00577     +/-  0.0016       False
# ------------------------------------------------------------------
# | FCN = -2412                   |      Ncalls=68 (68 total)      |
# | EDM = 1.37e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                     value    minuit_hesse    at limit
# -------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.325         740     +/-      37       False
# n_bkg_tau|BDT0.325         559     +/-      34       False
# mu_tau|BDT0.325           1968     +/-    0.45       False
# sigma_tau|BDT0.325       9.079     +/-    0.43       False
# lambda_tau|BDT0.325  -0.005768     +/-  0.0016       False
# Time to do the fit:  3.39127877199644
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/all_common_cutDeltaM_Ds23pi_V8/tau_M_all_common_cutDeltaM_Ds23pi_V8_fit_BDT0.325.pdf
# 0.03719821099260243
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/all_common_cutDeltaM_Ds23pi_V8_BDT0.325_params.json
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_sWeights_BDT0.325.root
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_BDT0.325.root
# ================================ cut_BDT = 0.35 ================================
# cut_BDT_ref = 0.325
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/tau_M_all_common_cutDeltaM_Ds23pi_V8_BDT0.35.pdf
# ------------------------------------------------------------------
# | FCN = -1351                   |     Ncalls=123 (123 total)     |
# | EDM = 8.59e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                    value    minuit_hesse    at limit
# ------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.35       513.3     +/-      32       False
# n_bkg_tau|BDT0.35       403.9     +/-      30       False
# mu_tau|BDT0.35           1968     +/-     0.6       False
# sigma_tau|BDT0.35       9.887     +/-    0.58       False
# lambda_tau|BDT0.35  -0.006732     +/-  0.0019       False
# ------------------------------------------------------------------
# | FCN = -1351                   |      Ncalls=65 (65 total)      |
# | EDM = 1.04e-05 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                   value    minuit_hesse    at limit
# ------------------  --------  --------------  ----------
# n_sig_tau|BDT0.35      513.2     +/-      32       False
# n_bkg_tau|BDT0.35      403.7     +/-      30       False
# mu_tau|BDT0.35          1968     +/-     0.6       False
# sigma_tau|BDT0.35      9.888     +/-    0.58       False
# lambda_tau|BDT0.35  -0.00675     +/-  0.0019       False
# Time to do the fit:  3.269399147000513
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/all_common_cutDeltaM_Ds23pi_V8/tau_M_all_common_cutDeltaM_Ds23pi_V8_fit_BDT0.35.pdf
# 0.07252832611966266
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/all_common_cutDeltaM_Ds23pi_V8_BDT0.35_params.json
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_sWeights_BDT0.35.root
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_BDT0.35.root
# ================================ cut_BDT = 0.375 ================================
# cut_BDT_ref = 0.35
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/tau_M_all_common_cutDeltaM_Ds23pi_V8_BDT0.375.pdf
# ------------------------------------------------------------------
# | FCN = -691                    |     Ncalls=150 (150 total)     |
# | EDM = 0.000554 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                     value    minuit_hesse    at limit
# -------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.375       350.5     +/-      27       False
# n_bkg_tau|BDT0.375       280.4     +/-      26       False
# mu_tau|BDT0.375           1968     +/-    0.75       False
# sigma_tau|BDT0.375          10     +/-    0.76       False
# lambda_tau|BDT0.375  -0.007655     +/-  0.0023       False
# ------------------------------------------------------------------
# | FCN = -691                    |      Ncalls=68 (68 total)      |
# | EDM = 4.8e-05 (Goal: 0.001)   |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                     value    minuit_hesse    at limit
# -------------------  ---------  --------------  ----------
# n_sig_tau|BDT0.375       350.7     +/-      27       False
# n_bkg_tau|BDT0.375       280.3     +/-      26       False
# mu_tau|BDT0.375           1968     +/-    0.75       False
# sigma_tau|BDT0.375       9.992     +/-    0.76       False
# lambda_tau|BDT0.375  -0.007709     +/-  0.0023       False
# Time to do the fit:  3.4531077130013728
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/all_common_cutDeltaM_Ds23pi_V8/tau_M_all_common_cutDeltaM_Ds23pi_V8_fit_BDT0.375.pdf
# 0.08025551722804557
# parameters saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/json/all_common_cutDeltaM_Ds23pi_V8_BDT0.375_params.json
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_sWeights_BDT0.375.root
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/ipykernel_launcher.py:144: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/root/common/common_B0toDstDs_BDT0.375.root
