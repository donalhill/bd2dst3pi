# %% [markdown]
# # Name data: `common_Dstto3piHEP_BDT{cut_BDT}`
#
# # Compute the sWeights
# For a given cut on the `BDT` value, with the starting value of the fit chosen as the result of the previous fit, specified by `cut_BDT_ref`
#
# 1. Fit on $m(3\pi)$ for $|m(3\pi) - 1968|<50$
#     - Signal shape: Gaussian
#     - Background shape: Exponential
# 2. Compute the associated probability and sWeights
# 3. Plot the sWeight (as a check)
# 4. Save the full dataframe in a root file, with the sWeight
#
# The sWeights are computed with `hepstats` (and not `hep_ml`). This is why I added `HEP` to the name of the data.
#
# The saved root file is already cut on the `BDT` output, and has a new column `sWeight`. The root files are saved in `output/root/common_Dstto3piHEP/`

# %%
data_name = 'common_DstTO3pi'
BDT_name = 'gradient'

# %%
import zfit
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from hepstats.splot import compute_sweights
import timeit
from scipy.stats import pearsonr

from bd2dst3pi.locations import loc
from bd2dst3pi.definition import years, magnets, latex_params_tau
from bd2dst3pi.pandas_root import load_data, add_constr_Dst


import sys
sys.path.append(loc.ROOT + 'library/')

from HEA.plot import plot_hist_auto, plot_hist, plot_hist2d_auto
from HEA.plot.fit import plot_hist_fit_auto
from HEA.fit import json_to_latex_table, retrieve_params, show_latex_table
from HEA.fit.fit import launch_fit, save_params, define_zparams, check_fit
from HEA.tools import show_dictionnary
from HEA.plot.tools import save_fig, show_grid
from HEA.tools.serial import dump_pickle
from HEA.pandas_root import save_root, load_saved_root
# Out:
# Welcome to JupyROOT 6.22/02

# %% [markdown]
# ## INIT

# %% [markdown]
# ### Retrieve data

# %%
# load_data does the cut on DeltaM and tau_M (around m(Ds)).
df_common_Ds = load_saved_root('common_'+BDT_name, folder_name='common', vars=['B0_M', 'tau_M', 'Dst_M', 'BDT'])
df_common_Ds = add_constr_Dst(df_common_Ds)
# Out:
# Loading /afs/cern.ch/user/c/correian/bd2dst3pi/output//root/common/common_gradient.root

# %%
plot_hist_auto({'data': df_common_Ds}, 'BDT',
              n_bins=100, bar_mode=False, colors=['orange', 'cyan'], pos_text_LHC=[0.05,0.95,'left'])
# Out:
# Figure saved in /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots//data/BDT_data
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='BDT', ylabel='Candidates / (0.187)'>)

# %% [markdown]
# ### BDT cuts

# %% [markdown]
# Reference fit whose results are taken as the starting values of the new fit.
# It is specified by `cut_BDT_ref`, the cut on the `BDT` output.
# If None, the reference fit is the one performed without any cut on the `BDT` output.

# %%
# def round_int(n):
#     if n%1==0:
#         return int(n)
#     else:
#         return n

# l_BDT = []
# l_BDT_ref = []
# starting_value = -4
# end_value      =  1.75
# step           = 0.25


# value = starting_value
# while value <= end_value:
#     if value==0:
#         value = 0
    
# #     if value%0.5!=0:
#     l_BDT.append(round_int(value))

#     if value <= -4:
#         l_BDT_ref.append(None)
#     else:
#         BDT_ref = np.round(l_BDT[-1] - step, 4)
#         BDT_ref = round_int(BDT_ref)
#         l_BDT_ref.append(BDT_ref)

#     value = np.round(value + step, 3)

l_BDT = [-6]
l_BDT_ref = [None]

# %%
l_BDT_ref
# Out:
# [None]

# %%
l_BDT
# Out:
# [-6]

# %% [markdown]
# ### Range of the variable

# %%
size_tau_M = 50.
mean_tau_M = 1969.
low_tau_M = mean_tau_M - size_tau_M
high_tau_M = mean_tau_M + size_tau_M
df_Ds = df_common_Ds.query(f"abs(tau_M-{mean_tau_M})<={size_tau_M}")

# %% [markdown]
# ## LOOP

# %%
for cut_BDT, cut_BDT_ref in zip(l_BDT, l_BDT_ref):
    ## CUT ON BDT -------------------------------------------------------
    k = str(cut_BDT)
    df_Ds = df_Ds.query(f"BDT > {cut_BDT}")
    
    print(f"================================ cut_BDT = {k} ================================")
    print(f"cut_BDT_ref = {cut_BDT_ref}")
    
    ## REFERENCE BDT CUT ------------------------------------------------
    if cut_BDT_ref is None:
        params_r = retrieve_params(data_name, folder_name=data_name)
    else:
        data_BDT_name_ref = f"{data_name}_BDT{cut_BDT_ref}"
        params_r = retrieve_params(data_BDT_name_ref, folder_name=data_name)
        params_r = get_params_without_BDT(params_r)
    
    ### HISTOGRAM --------------------------------------------------------
#     plot_hist_auto({data_name:df_Ds},'tau_M', cut_BDT=cut_BDT,
#               n_bins = 100, bar_mode = False, colors='black')
    
    ### FITTING ----------------------------------------------------------
    ## Starting point ........................
    n_events_tau_M = len(df_Ds)
    initial_values_tau = {
        'mu_tau': {
            'value' : params_r['mu_tau'],
            'low': 1965.,
            'high': 1975.,     
        },
        'sigma_tau': {
            'value' : params_r['sigma_tau'],
            'low': 5.,
            'high': 15.,
        },
        'n_bkg_tau': {
            'value' : params_r['n_bkg_tau'],
            'low': 0,
            'high': n_events_tau_M,  
        },
        'n_sig_tau': {
            'value' : params_r['n_sig_tau'],
            'low': 0,
            'high': n_events_tau_M,  
        },
        'lambda_tau': {
            'value' : params_r['lambda_tau'],
            'low': -0.01,
            'high': -0.000001  
        }
    }
    
    ## Parameters .............................
    obs_tau = zfit.Space("x", limits=(low_tau_M, high_tau_M))
    zparams_tau = define_zparams(initial_values_tau, cut_BDT=cut_BDT)

    ## Name of the variables ..................
    latex_params_tau_BDT = {
        # Signal
        f'mu_tau|BDT{cut_BDT}'     :'$\mu_{S}$',
        f'sigma_tau|BDT{cut_BDT}'  :'$\sigma_{S}$',
        f'n_sig_tau|BDT{cut_BDT}'  :'$n_{S}$',
        # Combinatorial background
        f'n_bkg_tau|BDT{cut_BDT}'  :'$n_{B,c}$',
        f'lambda_tau|BDT{cut_BDT}' :'$\\lambda_{B,c}$',
    }
    
    ## PDFs ...................................
    gaussian_tau = zfit.pdf.Gauss(zparams_tau["mu_tau"],zparams_tau["sigma_tau"],obs=obs_tau)
    exponential_tau = zfit.pdf.Exponential(zparams_tau["lambda_tau"], obs=obs_tau)

    gaussian_ext_tau = gaussian_tau.create_extended(zparams_tau["n_sig_tau"])
    exp_ext_tau = exponential_tau.create_extended(zparams_tau["n_bkg_tau"])
    model_tau = zfit.pdf.SumPDF([gaussian_ext_tau, exp_ext_tau]) # gauss is folded by frac

    data_tau = zfit.Data.from_pandas(df_Ds['tau_M'],obs=obs_tau)
    
    ## Launch the fit .........................
    start = timeit.default_timer()
    result_tau, params_tau = launch_fit(model_tau, data_tau, extended=True)
    result_tau, params_tau = launch_fit(model_tau, data_tau, extended=True)
    stop = timeit.default_timer()
    print('Time to do the fit: ', stop - start) 
    fit_ok = check_fit(result_tau)
    if not fit_ok:
        print('=============================================================================================================================')
    
    ## Result of the fit ......................
    plot_hist_fit_auto(df_Ds,'tau_M', models = [model_tau,gaussian_ext_tau,exp_ext_tau], 
                           models_names = ["", '$D_S \\to 3\pi$',''], colors = ['b','r','y'],
                           obs=obs_tau, n_bins = 100,bar_mode = False, data_name=data_name+'_detail', 
                          params=params_tau,latex_params=latex_params_tau_BDT, fontsize_leg=15.,
                          cut_BDT=cut_BDT)
#     plot_hist_fit_auto(df_Ds,'tau_M', models = [model_tau,gaussian_ext_tau,exp_ext_tau], 
#                            models_names = ["", '$D_S \\to 3\pi$',''], colors = ['b','r','y'],
#                            obs=obs_tau, n_bins = 100,bar_mode = False, data_name=data_name, 
#                            fontsize_leg=16., pos_text_LHC='right',
#                           cut_BDT=cut_BDT)
    ## Correlation ...........................
    corr_B0_M_tau_M = pearsonr(df_Ds['tau_M'], df_Ds['B0_M'])[0]
    print(corr_B0_M_tau_M)
    
    ## Save the result .......................
    data_BDT_name = data_name + f'_BDT{cut_BDT}'
    save_params(params_tau, data_BDT_name, True, {'corr_B0_M_tau_M': corr_B0_M_tau_M,
                                                 'info_fit':str(result_tau.info['original'])}, folder_name=data_name)
    json_to_latex_table(data_BDT_name, data_name, latex_params_tau, {})
    ### SWEIGHTS -------------------------------------------------------------------
    ## Computation ...........................
    
    # Probability that the candidate is actually a Ds particle.
    mass = df_Ds['tau_M']
    probs = pd.DataFrame(dict(sig=gaussian_ext_tau.pdf(mass), bkg=exp_ext_tau.pdf(mass)))
    probs = probs.div(probs.sum(axis=1), axis=0) # normalisation
    # sWeights
    weights_hep = compute_sweights(model_tau, df_Ds['tau_M'])
    weights_sig = weights_hep[zparams_tau['n_sig_tau']]
    weights_bkg = weights_hep[zparams_tau['n_bkg_tau']]
    
    ## Analysis of the sWeights .............
#     fig, ax = plt.subplots(figsize=(8,6))

#     ax.plot(mass, probs.sig,'.', label='Signal')
#     ax.plot(mass, probs.bkg,'.', label='Background')

#     plt.xlim(low_tau_M, high_tau_M) 
#     plt.xlabel('$m(3\pi)$',fontsize=20)
#     plt.ylabel('Probability',fontsize=20)
    
#     plt.show()
#     plt.close()
    
#     fig, ax = plt.subplots(figsize=(8,6))

#     ax.plot(mass, sWeights.sig,'.', label='Signal')
#     ax.plot(mass, sWeights.bkg,'.', label='Background')

#     plt.xlim(low_tau_M, high_tau_M) 
#     pt.fix_plot(ax, factor_ymax=None)

#     plt.xlabel('$m(3\pi)$',fontsize=20)
#     plt.ylabel('sWeights',fontsize=20)

#     ymin, ymax = ax.get_ylim()
#     ax.set_ylim(ymin, ymax*1.1)

#     plt.show()
#     plt.close()
    
    ### Save the result ----------------------------------------------------------------
    
#     save_root(sWeights, data_BDT_name+'_sWeights', 'sWeights', folder_name=data_name)
    df_Ds['sWeight'] = weights_sig
    save_root(df_Ds, data_BDT_name, 'DecayTree', folder_name=data_name)
# Out:
# ================================ cut_BDT = -6 ================================
# cut_BDT_ref = None
# ------------------------------------------------------------------
# | FCN = -6.283e+04              |     Ncalls=130 (130 total)     |
# | EDM = 2.02e-06 (Goal: 0.001)  |            up = 0.5            |
# ------------------------------------------------------------------
# |  Valid Min.   | Valid Param.  | Above EDM | Reached call limit |
# ------------------------------------------------------------------
# |     True      |     True      |   False   |       False        |
# ------------------------------------------------------------------
# | Hesse failed  |   Has cov.    | Accurate  | Pos. def. | Forced |
# ------------------------------------------------------------------
# |     False     |     True      |   True    |   True    | False  |
# ------------------------------------------------------------------
# name                  value    minuit_hesse    at limit
# ...
