# %% [markdown]
# # Without sWeights: `common_Dst_constr_B0toDstDsWithmu2Free_BDT-1.25`
#
# # Plot the fit
#
# I just want to recreate the figure of the fit with BDT > -1.25, with the colors I cherish.

# %% [markdown]
# ## Import

# %%
import zfit
import json
import numpy as np
import timeit

from numpy.random import normal

from math import sqrt

from bd2dst3pi.locations import loc
from bd2dst3pi.definitions import years, magnets

import sys
sys.path.append(loc.SCRIPTS)

import sys
sys.path.append(loc.SCRIPTS)
from load_save_data import load_saved_root, load_data, add_constr_Dst, json_to_latex_table, retrieve_params, format_previous_params
import plot.histogram as h
from plot.fit import plot_hist_fit_particle
from fit import define_zparams, sum_crystalball
from variables import name_params, name_params_KPiPi

# %%
name_params_KPiPi_print = {}
for key, value in name_params_KPiPi.items():
    name_params_KPiPi_print[key+'_Kpipi'] = name_params_KPiPi[key]

# %%
#name_data = 'common_Dst_constr'
#name_data_B0toDstDs = 'common_B0toDstDs_Dst_constr'

name_data = 'common_Dst_constr_B0toDstDsWithmu2Free'
name_data_B0toDstDs = 'common_B0toDstDs_Dst_constr_mu2Free'

name_data_Dstto3pi = 'common_Dstto3pi' # same as sWeights as the unconstrained case

name_BDT = 'gradient_bkgHighB0M'

name_data_MC = 'MC_constr_opposedCB_sharedMean'
name_data_KPiPi = "data_KPiPi_constr"

BDT = -1.25

# %% [markdown]
# ## Load

# %% [markdown]
# ### Json files

# %%
name_data_BDT = f"{name_data}_BDT{BDT}"
name_data_B0toDstDs_BDT = f"{name_data_B0toDstDs}_BDT{BDT}"

# Fixed alphaL, alphaR and nL
common_params = retrieve_params(name_data, name_folder=name_data)
# Fixed nR
MC_params = retrieve_params(name_data_MC, name_folder='MC')

# B0->DstKPiPi
Kpipi_params = retrieve_params(name_data_KPiPi, name_folder='data_KPiPi') # already in MeV 

# common with BDT cut (for startning values of the fit)
pipipi_params = format_previous_params(retrieve_params(name_data_BDT, name_folder=name_data), True)
# B0->DstDs with BDT cut (for the B0->DstDs PDF shape)
DstDs_params = format_previous_params(retrieve_params(name_data_B0toDstDs_BDT, name_folder=name_data_B0toDstDs), True)

# %% [markdown]
# Load
# - `f_params_dict['1']` - the fixed parameters that will be changed in **mode 1**
# - `f_params_dict['2']`  - the fixed parameters that will be changed in **mode 2**

# %%
f_params = {} # fixed parameters

for param in 'alphaL', 'alphaR', 'nL', 'r_bkgK':
    f_params[param] = common_params[param] # nominal value

f_params['nR'] = {}
f_params['nR']= MC_params['nR_MC']

for param in 'muL', 'muR', 'nL', 'nR', 'alphaR', 'alphaL', 'sigmaL', 'sigmaR', 'fraction':
    f_params[param+'_Kpipi'] = {}
    f_params[param+'_Kpipi'] = Kpipi_params[param]
    f_params[param+'_Kpipi'] = Kpipi_params[param+'_err']

# %%
df = load_saved_root('common_'+name_BDT, name_folder='common', vars=['B0_M', 'Dst_M', 'BDT'])
df = df.query(f"BDT > {BDT}")
df = add_constr_Dst(df)
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output//root/common/common_gradient_bkgHighB0M.root

# %%
h.plot_hist_particle({'data\_cut\_-1.25': df},'BDT',
              n_bins = 100, mode_hist = False, colors=['orange', 'cyan'], pos_text_LHC=[0.1,0.2,'left'])
# Out:
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/BDT_data_cut_-1.25
# (<Figure size 576x432 with 1 Axes>,
#  <AxesSubplot:xlabel='BDT', ylabel='Candidates / (0.06)'>)

# %% [markdown]
# ## Range of the variables

# %% [markdown]
# ### Constrained $m(D^* 3\pi)$ of the `common` data

# %%
var = 'Dst_constr_B0_M'
low = 5150.
high = 5545.

# %% [markdown]
# ## PLOT

# %% [markdown]
# ### Values

# %%
initial_values = {
    # Signal        
    'mu'       :{ 'value': pipipi_params['mu']       , 'floating': True},
    'sigmaL'   :{ 'value': pipipi_params['sigmaL']   , 'floating': True},
    'sigmaR'   :{ 'value': pipipi_params['sigmaR']   , 'floating': True},
    'frac'     :{ 'value': pipipi_params['frac']     , 'floating': True},
    'n_sig'    :{ 'value': pipipi_params['n_sig']    , 'floating': True},
    # Combinatorial background        
    'lambda'   :{ 'value': pipipi_params['lambda']   , 'floating': True},
    'n_bkg'    :{ 'value': pipipi_params['n_bkg']    , 'floating': True},
    # Background decay D*Kpipi    
}

# Fixed parameters:
for param, value_param in f_params.items():
    initial_values[param] = {}
    initial_values[param]['value'] = value_param
    initial_values[param]['floating'] = False

# B0 -> D* Ds distribution
for vari in 'mu', 'sigma', 'n_sig' :
    initial_values[f'{vari}_Ds'] = {'value': DstDs_params[f'{vari}_B0Ds'], 'floating': False}

# %% [markdown]
# ### Observables and variables

# %%
obs = zfit.Space("x", limits=(low, high))

zparams = define_zparams(initial_values, num=8)

mult = lambda r, n: r*n
zparams["n_bkgK"] = zfit.ComposedParameter(f"n_bkgK;8", mult, params=[zparams['r_bkgK'],zparams['n_sig']])

# %% [markdown]
# ### PDFs

# %%
model_S, crystalBallL_S, crystalBallR_S = sum_crystalball(zparams['mu'], zparams['mu'],
                                                          zparams['sigmaL'], zparams['sigmaR'],
                                                          zparams['frac'], obs,                                                          
                                                          zparams['alphaL'], zparams['alphaR'], 
                                                          zparams['nL'], zparams['nR']
                                                         )


gaussian_B0Ds = zfit.pdf.Gauss(zparams['mu_Ds'],zparams['sigma_Ds'],obs=obs)

model_K, crystalBallL_K, crystalBallR_K = sum_crystalball(zparams['muL_Kpipi'], zparams['muR_Kpipi'], 
                                                          zparams['sigmaL_Kpipi'], zparams['sigmaR_Kpipi'],
                                                          zparams['fraction_Kpipi'], obs,
                                                          zparams['alphaL_Kpipi'], zparams['alphaR_Kpipi'], 
                                                          zparams['nL_Kpipi'], zparams['nR_Kpipi'])

exponential = zfit.pdf.Exponential(zparams['lambda'], obs=obs)


model_S_ext = model_S.create_extended(zparams['n_sig'])
exp_ext = exponential.create_extended(zparams['n_bkg'])
gaussian_B0Ds_ext = gaussian_B0Ds.create_extended(zparams['n_sig_Ds'])
model_K_ext = model_K.create_extended(zparams['n_bkgK'])

model = zfit.pdf.SumPDF([model_S_ext, gaussian_B0Ds_ext, model_K_ext, exp_ext]) # gauss is folded by frac

# %% [markdown]
# ### Plotting

# %%
name_data_plot = name_data_BDT + '_details'
plot_hist_fit_particle(df, var, models = [model,[model_S_ext, crystalBallL_S, crystalBallR_S], gaussian_B0Ds_ext, model_K_ext,exp_ext],
                       name_models = ["", '\n $B^0\\to D^* 3\pi$','\n $B^0\\to D^*D_s$','\n $B^0\\to D^*3\pi h$',
                                      '\n $B^0\\to D^* K \pi^+\pi^-$','\n (combinatorial)'],
                       obs=obs, n_bins = 100,mode_hist = False,
                       name_data = name_data_plot, name_folder=name_data_BDT,
                       colors=['b','g','r','saddlebrown','y'],
                       fontsize_leg=13.5, show_chi2=True,
                       colWidths=[0.06,0.01,0.05,0.06], 
                      )
# Out:
# WARNING:tensorflow:5 out of the last 8 calls to <function crystalball_func at 0x7fa2a0781e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 9 calls to <function crystalball_func at 0x7fa2a0781e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# ---------------------------------------------------------------------------
# InvalidArgumentError                      Traceback (most recent call last)
# <ipython-input-46-b61d0c0bf482> in <module>
#       7                        colors=['b','g','r','saddlebrown','y'],
#       8                        fontsize_leg=13.5, show_chi2=True,
# ----> 9                        colWidths=[0.06,0.01,0.05,0.06],
#      10                       )
#
# ~/bd2dst3pi/scripts/plot/fit.py in plot_hist_fit_particle(df, variable, cut_BDT, **kwargs)
#     620         kwargs['name_folder'] = kwargs['name_data']
#     621
# --> 622     return plot_hist_fit(df, variable, name_var=name_variable, unit_var=unit_var, **kwargs)
#
# ~/bd2dst3pi/scripts/plot/fit.py in plot_hist_fit(df, variable, name_var, unit_var, models, obs, n_bins, color, name_models, type_models, mode_hist, linewidth, colors, name_data_title, title, fontsize_leg, name_file, name_folder, name_data, show_chi2, params, name_params, colWidths, fontsize_res, loc_res, loc_leg, weights, save_fig, pos_text_LHC, show_leg)
#     543     plot_scaling = get_plot_scaling(counts, obs, n_bins)
#     544     plot_fitted_curves(ax[0], models, plot_scaling, low, high, name_models=name_models, type_models=type_models,
# --> 545                        line_width=2.5, colors=colors, fontsize_legend=fontsize_leg, loc_leg=loc_leg, show_legend=show_leg)
#     546
#     547     pt.change_ymax(ax[0], factor=1.1)
#
# ~/bd2dst3pi/scripts/plot/fit.py in plot_fitted_curves(ax, models, plot_scaling, low, high, name_models, type_models, line_width, colors, fontsize_legend, loc_leg, show_legend)
#     396             type_models += 'b'*(len(name_models)-2)
#     397
# --> 398     plot_models(ax, x, models, plot_scaling, type_models, name_models=name_models, colors=colors, line_width=2.5)
#     399
#     400
#
# ~/bd2dst3pi/scripts/plot/fit.py in plot_models(ax, x, models, plot_scaling, type_models, name_models, frac, l, colors, linestyles, line_width)
#     343
#     344             plot_models(ax, x, model, plot_scaling, type_model, name_model, applied_frac, l, color,
# --> 345                         linestyles, line_width)
#     346
#     347     else:
#
# ~/bd2dst3pi/scripts/plot/fit.py in plot_models(ax, x, models, plot_scaling, type_models, name_models, frac, l, colors, linestyles, line_width)
#     363
#     364         plot_fitted_curve(ax, model, plot_scaling, frac=frac, line_width=line_width, color=colors,
# --> 365                           linestyle = linestyles[l], label=label_model, x=x, alpha=alpha)
#     366
#     367
#
# ~/bd2dst3pi/scripts/plot/fit.py in plot_fitted_curve(ax, model, plot_scaling, frac, line_width, color, linestyle, low, high, label, x, alpha)
#     186     if x is None:
#     187         x = np.linspace(low, high, 1000)
# --> 188     y = frac_model(x, model, frac=frac)* plot_scaling
#     189     ax.plot(x, y, linewidth=line_width, color=color, ls=linestyle, label=label, alpha=alpha)
#     190
#
# ~/bd2dst3pi/scripts/plot/fit.py in frac_model(x, model, frac)
#      52     else:
#      53
# ---> 54         return (model.pdf(x)*frac).numpy()
#      55
#      56 ### number of degrees of freedom =============================
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/z/zextension.py in concrete_func(*args, **kwargs)
#     191
#     192             if not self.do_jit or func in self.currently_traced:
# --> 193                 return func(*args, **kwargs)
#     194
#     195             assert self.all_wrapped_functions_registered()
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in pdf(self, x, norm_range)
#     301         norm_range = self._check_input_norm_range(norm_range, none_is_error=True)
#     302         with self._convert_sort_x(x) as x:
# --> 303             value = self._single_hook_pdf(x=x, norm_range=norm_range)
#     304             if run.numeric_checks:
#     305                 z.check_numerics(value, message="Check if pdf output contains any NaNs of Infs")
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in _single_hook_pdf(self, x, norm_range)
#     307
#     308     def _single_hook_pdf(self, x, norm_range):
# --> 309         return self._hook_pdf(x=x, norm_range=norm_range)
#     310
#     311     def _hook_pdf(self, x, norm_range):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in _hook_pdf(self, x, norm_range)
#     310
#     311     def _hook_pdf(self, x, norm_range):
# --> 312         return self._norm_pdf(x=x, norm_range=norm_range)
#     313
#     314     def _norm_pdf(self, x, norm_range):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in _norm_pdf(self, x, norm_range)
#     313
#     314     def _norm_pdf(self, x, norm_range):
# --> 315         return self._call_pdf(x=x, norm_range=norm_range)
#     316
#     317     def _call_pdf(self, x, norm_range):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in _call_pdf(self, x, norm_range)
#     317     def _call_pdf(self, x, norm_range):
#     318         with suppress(FunctionNotImplementedError):
# --> 319             return self._pdf(x, norm_range=norm_range)
#     320         with suppress(FunctionNotImplementedError):
#     321             return tf.exp(self._log_pdf(x=x, norm_range=norm_range))
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/models/functor.py in _pdf(self, x, norm_range)
#     202         pdfs = self.pdfs
#     203         fracs = self.params.values()
# --> 204         probs = [pdf.pdf(x) * frac for pdf, frac in zip(pdfs, fracs)]
#     205         prob = functools.reduce(operator.add, probs)
#     206         # prob = tf.math.accumulate_n([pdf.pdf(x) * frac for pdf, frac in zip(pdfs, fracs)])
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/models/functor.py in <listcomp>(.0)
#     202         pdfs = self.pdfs
#     203         fracs = self.params.values()
# --> 204         probs = [pdf.pdf(x) * frac for pdf, frac in zip(pdfs, fracs)]
#     205         prob = functools.reduce(operator.add, probs)
#     206         # prob = tf.math.accumulate_n([pdf.pdf(x) * frac for pdf, frac in zip(pdfs, fracs)])
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/z/zextension.py in concrete_func(*args, **kwargs)
#     191
#     192             if not self.do_jit or func in self.currently_traced:
# --> 193                 return func(*args, **kwargs)
#     194
#     195             assert self.all_wrapped_functions_registered()
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in pdf(self, x, norm_range)
#     301         norm_range = self._check_input_norm_range(norm_range, none_is_error=True)
#     302         with self._convert_sort_x(x) as x:
# --> 303             value = self._single_hook_pdf(x=x, norm_range=norm_range)
#     304             if run.numeric_checks:
#     305                 z.check_numerics(value, message="Check if pdf output contains any NaNs of Infs")
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in _single_hook_pdf(self, x, norm_range)
#     307
#     308     def _single_hook_pdf(self, x, norm_range):
# --> 309         return self._hook_pdf(x=x, norm_range=norm_range)
#     310
#     311     def _hook_pdf(self, x, norm_range):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in _hook_pdf(self, x, norm_range)
#     310
#     311     def _hook_pdf(self, x, norm_range):
# --> 312         return self._norm_pdf(x=x, norm_range=norm_range)
#     313
#     314     def _norm_pdf(self, x, norm_range):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in _norm_pdf(self, x, norm_range)
#     313
#     314     def _norm_pdf(self, x, norm_range):
# --> 315         return self._call_pdf(x=x, norm_range=norm_range)
#     316
#     317     def _call_pdf(self, x, norm_range):
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in _call_pdf(self, x, norm_range)
#     317     def _call_pdf(self, x, norm_range):
#     318         with suppress(FunctionNotImplementedError):
# --> 319             return self._pdf(x, norm_range=norm_range)
#     320         with suppress(FunctionNotImplementedError):
#     321             return tf.exp(self._log_pdf(x=x, norm_range=norm_range))
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/models/functor.py in _pdf(self, x, norm_range)
#     202         pdfs = self.pdfs
#     203         fracs = self.params.values()
# --> 204         probs = [pdf.pdf(x) * frac for pdf, frac in zip(pdfs, fracs)]
#     205         prob = functools.reduce(operator.add, probs)
#     206         # prob = tf.math.accumulate_n([pdf.pdf(x) * frac for pdf, frac in zip(pdfs, fracs)])
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/models/functor.py in <listcomp>(.0)
#     202         pdfs = self.pdfs
#     203         fracs = self.params.values()
# --> 204         probs = [pdf.pdf(x) * frac for pdf, frac in zip(pdfs, fracs)]
#     205         prob = functools.reduce(operator.add, probs)
#     206         # prob = tf.math.accumulate_n([pdf.pdf(x) * frac for pdf, frac in zip(pdfs, fracs)])
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/z/zextension.py in concrete_func(*args, **kwargs)
#     191
#     192             if not self.do_jit or func in self.currently_traced:
# --> 193                 return func(*args, **kwargs)
#     194
#     195             assert self.all_wrapped_functions_registered()
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/core/basepdf.py in pdf(self, x, norm_range)
#     303             value = self._single_hook_pdf(x=x, norm_range=norm_range)
#     304             if run.numeric_checks:
# --> 305                 z.check_numerics(value, message="Check if pdf output contains any NaNs of Infs")
#     306             return z.to_real(value)
#     307
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/zfit/z/wrapping_tf.py in check_numerics(tensor, message, name)
#      70         check_op = tf.group(real_check, imag_check)
#      71     else:
# ---> 72         check_op = tf.debugging.check_numerics(tensor=tensor, message=message, name=name)
#      73     return check_op
#      74
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/tensorflow/python/ops/gen_array_ops.py in check_numerics(tensor, message, name)
#     913       return _result
#     914     except _core._NotOkStatusException as e:
# --> 915       _ops.raise_from_not_ok_status(e, name)
#     916     except _core._FallbackException:
#     917       pass
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/tensorflow/python/framework/ops.py in raise_from_not_ok_status(e, name)
#    6841   message = e.message + (" name: " + name if name is not None else "")
#    6842   # pylint: disable=protected-access
# -> 6843   six.raise_from(core._status_to_exception(e.code, message), None)
#    6844   # pylint: enable=protected-access
#    6845
#
# /afs/cern.ch/work/c/correian/miniconda/envs/bd2dst3pi_env/lib/python3.7/site-packages/six.py in raise_from(value, from_value)
#
# InvalidArgumentError: Check if pdf output contains any NaNs of Infs : Tensor had NaN values [Op:CheckNumerics]

# %%
name_data_plot = name_data_BDT
plot_hist_fit_particle(df,var, models = [model,model_S_ext, gaussian_B0Ds_ext, model_K_ext,exp_ext],
                       name_models = ["", '\n $B^0\\to D^* 3\pi$','\n $B^0\\to D^*D_s$','\n $B^0\\to D^*3\pi h$',
                                      '\n $B^0\\to D^* K \pi^+\pi^-$','\n (combinatorial)'],
                       obs=obs, n_bins = 100,mode_hist = False,
                       name_data = name_data_plot, name_folder=name_data_BDT,
                       colors=['b','g','r','saddlebrown','y'], loc_leg='best',
                       fontsize_leg=20., pos_text_LHC=[0.95, 0.30, 'right'],
                      )
# Out:
# WARNING:tensorflow:5 out of the last 11 calls to <function crystalball_func at 0x7fa2a0781e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# WARNING:tensorflow:6 out of the last 12 calls to <function crystalball_func at 0x7fa2a0781e60> triggered tf.function retracing. Tracing is expensive and the excessive number of tracings could be due to (1) creating @tf.function repeatedly in a loop, (2) passing tensors with different shapes, (3) passing Python objects instead of tensors. For (1), please define your @tf.function outside of the loop. For (2), @tf.function has experimental_relax_shapes=True option that relaxes argument shapes that can avoid unnecessary retracing. For (3), please refer to https://www.tensorflow.org/tutorials/customization/performance#python_or_tensor_args and https://www.tensorflow.org/api_docs/python/tf/function for  more details.
# Number of d.o.f. in the model:  4
# Reduced chi2:  51.28291922524385
# /afs/cern.ch/user/c/correian/bd2dst3pi/output/plots/common_Dst_constr_B0toDstDsWithmu2Free_BDT-1.25/Dst_constr_B0_M_common_Dst_constr_B0toDstDsWithmu2Free_BDT-1.25_fit
# (<Figure size 864x720 with 2 Axes>,
#  <AxesSubplot:xlabel='$m$($B^0|m(D_s)$=2010.26 MeV/$c^2$) [MeV/$c^2$]', ylabel='Candidates / (4 MeV/$c^2$)'>,
#  <AxesSubplot:ylabel='residuals / $\\sigma$'>)

# %%
name_data_plot = name_data_BDT
plot_hist_fit_particle(df,var, models = [model,model_S_ext, gaussian_B0Ds_ext, model_K_ext,exp_ext],
                       name_models = ["", '\n $B^0\\to D^* 3\pi$','\n $B^0\\to D^*D_s$','\n $B^0\\to D^*3\pi h$',
                                      '\n $B^0\\to D^* K \pi^+\pi^-$','\n (combinatorial)'],
                       obs=obs, n_bins = 100,mode_hist = False,
                       name_data = name_data_plot, name_folder=name_data_BDT,
                       colors=['b','g','r','saddlebrown','y'], loc_leg='best',
                       fontsize_leg=20., pos_text_LHC=[0.95, 0.30, 'right'],
                      )
